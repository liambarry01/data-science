# %% [markdown]
# # Data Processing and Visualization
# -----
# **Assignment Topic: Data Analysis on Car Advertisements**
#
# Group Number: 6
#
# Student1 Name: Liam Barry
#
# SNumber: 5221080
#
# Student2 Name: Ben White
#
# SNumber: 2850345
#
# Student3 Name: Trieu Duong Phan
#
# SNumber: ...

# %% [markdown]
# # Data Import

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OrdinalEncoder
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import sqlite3
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
car_data = pd.read_csv("car_dataset.csv")
sellers_data = pd.read_csv('seller_dataset.csv')

# %% [markdown]
# # 1. Data Formatting

# %% [markdown]
# ## a. Numerical Conversion

# %%
def numerical_conversion(df, columns):

    for column in columns:
        if df[column].astype(str).str.contains("L/100Km", regex=False).any():
            df[column] = df[column].replace("L/100Km", "", regex=True)
            df[column] = df[column].str.extract(r"(\d*\.?\d+)", expand=False)
        else:
            df[column] = df[column].replace(r"[^\d.]", "", regex=True)
        
        df[column] = df[column].astype(float)

    return df

columns_to_convert = ['mileage', 'num_of_doors', 'seating_capacity', 'fuel_consumption', 'price (AUD)']

car_data = numerical_conversion(car_data, columns_to_convert)

car_data[['num_of_doors', 'seating_capacity']] = car_data[['num_of_doors', 'seating_capacity']].astype(int)

car_data.head()
# Out:
#    ad_id             origin condition  car_model  mileage exterior_color  \
# 0  17042  Domestic assembly   New car      Truck      0.0          White
# 1  53794           Imported   New car        SUV      0.0          Black
# 2  73954  Domestic assembly   New car  Crossover      0.0         Silver
# 3  74150           Imported   New car        SUV      0.0          White
# 4  87573  Domestic assembly   New car  Crossover      0.0         Silver
#
#   interior_color  num_of_doors  seating_capacity         engine fuel_system  \
# 0           gray             2                 2  Petrol\t1.0 L         NaN
# 1          Black             5                 7  Petrol\t3.4 L         NaN
# 2          Brown             5                 8  Petrol\t2.0 L         NaN
# 3          Black             5                 5  Petrol\t1.8 L         NaN
# 4           gray             5                 8  Petrol\t2.0 L         NaN
#
#   transmission                 drive_type  fuel_consumption   brand  \
# 0       Manual     RFD - Rear-wheel drive               NaN  Suzuki
# 1    Automatic  AWD - 4-wheel drive (AWD)              10.0  Toyota
# 2    Automatic     RFD - Rear-wheel drive               NaN  Toyota
# 3    Automatic    FWD - Front-wheel drive               NaN  Toyota
# 4    Automatic     RFD - Rear-wheel drive               NaN  Toyota
#
#                grade  year_of_manufacture  \
# 0  Super Carry Truck               2022.0
# 1       Land Cruiser               2022.0
# 2             Innova               2023.0
# 3      Corolla Cross               2023.0
# 4             Innova               2022.0
#
#                                car_name   price (AUD)
# 0  Suzuki Super Carry Truck 1.0 MT 2022   10080.99411
# 1       Toyota Land Cruiser 3.5 V6 2022  161943.68050
# 2       Toyota Innova G 2.0 AT 2023 car   35830.03930
# 3        Toyota Corolla Cross 1.8G 2023   30526.38376
# 4       Toyota Innova G 2.0 AT 2022 car   34413.03209

# %% [markdown]
# ## b. Engine Feature Split

# %%
engine_split = car_data['engine'].str.split("\t", expand=True)
car_data['type_of_engine'] = engine_split[0]
car_data['engine_capacity'] = engine_split[1]

car_data.drop('engine', axis=1, inplace=True)

car_data = numerical_conversion(car_data, ['engine_capacity'])

car_data.head()
# Out:
#    ad_id             origin condition  car_model  mileage exterior_color  \
# 0  17042  Domestic assembly   New car      Truck      0.0          White
# 1  53794           Imported   New car        SUV      0.0          Black
# 2  73954  Domestic assembly   New car  Crossover      0.0         Silver
# 3  74150           Imported   New car        SUV      0.0          White
# 4  87573  Domestic assembly   New car  Crossover      0.0         Silver
#
#   interior_color  num_of_doors  seating_capacity fuel_system transmission  \
# 0           gray             2                 2         NaN       Manual
# 1          Black             5                 7         NaN    Automatic
# 2          Brown             5                 8         NaN    Automatic
# 3          Black             5                 5         NaN    Automatic
# 4           gray             5                 8         NaN    Automatic
#
#                   drive_type  fuel_consumption   brand              grade  \
# 0     RFD - Rear-wheel drive               NaN  Suzuki  Super Carry Truck
# 1  AWD - 4-wheel drive (AWD)              10.0  Toyota       Land Cruiser
# 2     RFD - Rear-wheel drive               NaN  Toyota             Innova
# 3    FWD - Front-wheel drive               NaN  Toyota      Corolla Cross
# 4     RFD - Rear-wheel drive               NaN  Toyota             Innova
#
#    year_of_manufacture                              car_name   price (AUD)  \
# 0               2022.0  Suzuki Super Carry Truck 1.0 MT 2022   10080.99411
# 1               2022.0       Toyota Land Cruiser 3.5 V6 2022  161943.68050
# 2               2023.0       Toyota Innova G 2.0 AT 2023 car   35830.03930
# 3               2023.0        Toyota Corolla Cross 1.8G 2023   30526.38376
# 4               2022.0       Toyota Innova G 2.0 AT 2022 car   34413.03209
#
#   type_of_engine  engine_capacity
# 0         Petrol              1.0
# 1         Petrol              3.4
# 2         Petrol              2.0
# 3         Petrol              1.8
# 4         Petrol              2.0

# %% [markdown]
# ## c. Standardizing Text Data

# %%
def standardize_text_data(df, columns):
    df[columns] = df[columns].apply(lambda x: x.str.lower())
    return df

columns_to_lowercase = ['origin', 'condition', 'car_model', 'exterior_color', 'interior_color', 'type_of_engine',
                        'fuel_system', 'transmission', 'drive_type', 'brand', 'grade']

car_data = standardize_text_data(car_data, columns_to_lowercase)

car_data.head()
# Out:
#    ad_id             origin condition  car_model  mileage exterior_color  \
# 0  17042  domestic assembly   new car      truck      0.0          white
# 1  53794           imported   new car        suv      0.0          black
# 2  73954  domestic assembly   new car  crossover      0.0         silver
# 3  74150           imported   new car        suv      0.0          white
# 4  87573  domestic assembly   new car  crossover      0.0         silver
#
#   interior_color  num_of_doors  seating_capacity fuel_system transmission  \
# 0           gray             2                 2         NaN       manual
# 1          black             5                 7         NaN    automatic
# 2          brown             5                 8         NaN    automatic
# 3          black             5                 5         NaN    automatic
# 4           gray             5                 8         NaN    automatic
#
#                   drive_type  fuel_consumption   brand              grade  \
# 0     rfd - rear-wheel drive               NaN  suzuki  super carry truck
# 1  awd - 4-wheel drive (awd)              10.0  toyota       land cruiser
# 2     rfd - rear-wheel drive               NaN  toyota             innova
# 3    fwd - front-wheel drive               NaN  toyota      corolla cross
# 4     rfd - rear-wheel drive               NaN  toyota             innova
#
#    year_of_manufacture                              car_name   price (AUD)  \
# 0               2022.0  Suzuki Super Carry Truck 1.0 MT 2022   10080.99411
# 1               2022.0       Toyota Land Cruiser 3.5 V6 2022  161943.68050
# 2               2023.0       Toyota Innova G 2.0 AT 2023 car   35830.03930
# 3               2023.0        Toyota Corolla Cross 1.8G 2023   30526.38376
# 4               2022.0       Toyota Innova G 2.0 AT 2022 car   34413.03209
#
#   type_of_engine  engine_capacity
# 0         petrol              1.0
# 1         petrol              3.4
# 2         petrol              2.0
# 3         petrol              1.8
# 4         petrol              2.0

# %% [markdown]
# ## d. Numerical Scaling

# %%
numerical_columns = ['engine_capacity', 'num_of_doors', 'seating_capacity', 'fuel_consumption', 'price (AUD)']

scaler = MinMaxScaler()
car_data[['normalised_' + column for column in numerical_columns]] = scaler.fit_transform(car_data[numerical_columns])

car_data.head()
# Out:
#    ad_id             origin condition  car_model  mileage exterior_color  \
# 0  17042  domestic assembly   new car      truck      0.0          white
# 1  53794           imported   new car        suv      0.0          black
# 2  73954  domestic assembly   new car  crossover      0.0         silver
# 3  74150           imported   new car        suv      0.0          white
# 4  87573  domestic assembly   new car  crossover      0.0         silver
#
#   interior_color  num_of_doors  seating_capacity fuel_system  ...  \
# 0           gray             2                 2         NaN  ...
# 1          black             5                 7         NaN  ...
# 2          brown             5                 8         NaN  ...
# 3          black             5                 5         NaN  ...
# 4           gray             5                 8         NaN  ...
#
#   year_of_manufacture                              car_name   price (AUD)  \
# 0              2022.0  Suzuki Super Carry Truck 1.0 MT 2022   10080.99411
# 1              2022.0       Toyota Land Cruiser 3.5 V6 2022  161943.68050
# 2              2023.0       Toyota Innova G 2.0 AT 2023 car   35830.03930
# 3              2023.0        Toyota Corolla Cross 1.8G 2023   30526.38376
# 4              2022.0       Toyota Innova G 2.0 AT 2022 car   34413.03209
#
#   type_of_engine engine_capacity  normalised_engine_capacity  \
# 0         petrol             1.0                    0.071429
# 1         petrol             3.4                    0.261905
# 2         petrol             2.0                    0.150794
# 3         petrol             1.8                    0.134921
# 4         petrol             2.0                    0.150794
#
#   normalised_num_of_doors  normalised_seating_capacity  \
# 0                0.037037                     0.042553
# 1                0.092593                     0.148936
# 2                0.092593                     0.170213
# 3                0.092593                     0.106383
# 4                0.092593                     0.170213
#
#   normalised_fuel_consumption  normalised_price (AUD)
# 0                         NaN                0.004611
# 1                     0.00005                0.074074
# 2                         NaN                0.016389
# 3                         NaN                0.013963
# 4                         NaN                0.015741
#
# [5 rows x 25 columns]

# %%
# Save processed data to a new CSV file
car_data.to_csv("processed_car_dataset.csv", index=False)

# %% [markdown]
# # 2. Data Exploration and Cleaning

# %%
processed_car_data = pd.read_csv("processed_car_dataset.csv")

# %% [markdown]
# ## a. Statistics Computation

# %%
columns_to_calculate = ['price (AUD)', 'mileage', 'year_of_manufacture']

def calculate_range(column):
    return column.max() - column.min()

for column in columns_to_calculate:
    mean = processed_car_data[column].mean()
    median = processed_car_data[column].median()
    mode = processed_car_data[column].mode()[0]   # take the first mode if multiple exist
    std = processed_car_data[column].std()
    data_range = calculate_range(processed_car_data[column])

    stats_dict = {
        'Mean': mean,
        'Median': median,
        'Mode': mode,
        'Std Dev': std,
        'Range': data_range
    }

    stats_df = pd.DataFrame(stats_dict, index=[column]).T

    print(f"Calculated statistics for the variable '{column}':")
    display(stats_df)
# Out:
# Calculated statistics for the variable 'price (AUD)':
#           price (AUD)
# Mean     4.284316e+04
# Median   2.493933e+04
# Mode     4.048592e+04
# Std Dev  7.858559e+04
# Range    2.186240e+06
# Calculated statistics for the variable 'mileage':
#               mileage
# Mean     4.123150e+05
# Median   2.000000e+04
# Mode     0.000000e+00
# Std Dev  3.489966e+07
# Range    4.294967e+09
# Calculated statistics for the variable 'year_of_manufacture':
#          year_of_manufacture
# Mean             2017.320346
# Median           2019.000000
# Mode             2023.000000
# Std Dev             5.331772
# Range              33.000000

# %% [markdown]
# ## b. Outliers and Missing Values

# %% [markdown]
# ### i. Checking and addressing outliers

# %%
initial_rows = processed_car_data.shape[0]

# Select numerical variables (excluding ID column)
numerical_columns = processed_car_data.select_dtypes(include='number').columns.drop("ad_id")

# Calculate quartiles
Q1 = processed_car_data[numerical_columns].quantile(0.25)
Q3 = processed_car_data[numerical_columns].quantile(0.75)

# Interquartile range
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Create outlier mask
outlier_mask = (
    (processed_car_data[numerical_columns] < lower_bound) | 
    (processed_car_data[numerical_columns] > upper_bound)
)

# Count outliers per column
outlier_counts = outlier_mask.sum()

print("Outliers across all numerical columns:")
print(outlier_counts.to_string())
# Out:
# Outliers across all numerical columns:
# mileage                        1050
# num_of_doors                    769
# seating_capacity                225
# fuel_consumption                565
# year_of_manufacture             887
# price (AUD)                    3767
# engine_capacity                1076
# normalised_engine_capacity     1076
# normalised_num_of_doors         769
# normalised_seating_capacity     259
# normalised_fuel_consumption     576
# normalised_price (AUD)         3767

# %%
print("Percentage of outliers in the numerical columns:")
for column in numerical_columns:
    count = outlier_counts[column]
    if count > 0:
        percentage = (count / initial_rows) * 100 
        print(f"\t{column}: {percentage:.2f}%")

outlier_matrix = (processed_car_data[numerical_columns] < lower_bound) | (processed_car_data[numerical_columns] > upper_bound)

rows_with_outliers = outlier_matrix.any(axis=1)
percentage_unique_rows = (rows_with_outliers.sum() / processed_car_data.shape[0]) * 100

print(f"\nPercentage of rows with at least one outlier: {percentage_unique_rows:.2f}%")
# Out:
# Percentage of outliers in the numerical columns:
# 	mileage: 3.43%
# 	num_of_doors: 2.51%
# 	seating_capacity: 0.73%
# 	fuel_consumption: 1.84%
# 	year_of_manufacture: 2.89%
# 	price (AUD): 12.29%
# 	engine_capacity: 3.51%
# 	normalised_engine_capacity: 3.51%
# 	normalised_num_of_doors: 2.51%
# 	normalised_seating_capacity: 0.84%
# 	normalised_fuel_consumption: 1.88%
# 	normalised_price (AUD): 12.29%
#
# Percentage of rows with at least one outlier: 21.84%

# %%
def colourise_outliers(value, maxValue):
    low, high = maxValue * 0.2, maxValue * 0.66
    if value <= low:
        return 'lightgreen'   
    elif value >= high:
        return 'darkgreen'
    else:
        return 'green'

cols = [colourise_outliers(n, outlier_counts.max()) for n in outlier_counts]
total_data = [processed_car_data.shape[0]] * len(numerical_columns)

plt.figure(figsize=(20,10))
plt.barh(numerical_columns, total_data, color='aliceblue')
plt.barh(numerical_columns, outlier_counts, color=cols)

plt.title('Visualising the Outliers across all Numerical Variables', size=20)
plt.xlabel('Outliers vs. Existing Data', size=14)
plt.ylabel('Variable', size=14)

for index, value in enumerate(outlier_counts.values):
    plt.text(value + outlier_counts.max() * 0.05, index, str(value), va='center', ha='left', fontsize=12)

plt.show()

# %%
# Remove rows containing any outlier
cleaned_car_data = processed_car_data[~outlier_mask.any(axis=1)]
final_rows = cleaned_car_data.shape[0]

outliers_removed = initial_rows - final_rows
print(f"Number of outliers removed: {outliers_removed}")
# Out:
# Number of outliers removed: 6693

# %% [markdown]
# ### ii. Identifying and handling missing values

# %%
missing_data = cleaned_car_data.isna().sum()
print("Missing values across the dataset:")
print(missing_data.to_string())
# Out:
# Missing values across the dataset:
# ad_id                              0
# origin                             0
# condition                          0
# car_model                          0
# mileage                            0
# exterior_color                     0
# interior_color                     0
# num_of_doors                       0
# seating_capacity                   0
# fuel_system                    18697
# transmission                       0
# drive_type                         0
# fuel_consumption               14955
# brand                              0
# grade                              0
# year_of_manufacture               14
# car_name                           0
# price (AUD)                        0
# type_of_engine                     0
# engine_capacity                  718
# normalised_engine_capacity       718
# normalised_num_of_doors            0
# normalised_seating_capacity        0
# normalised_fuel_consumption    14955
# normalised_price (AUD)             0

# %%
print("Percentage of missing data in the dataset:")
totalPercentage = 0
for i in range(len(missing_data)):
    if missing_data.iloc[i] > 0:
        percentage = missing_data.iloc[i] / cleaned_car_data.shape[0]
        totalPercentage += percentage
        print(f"\t{cleaned_car_data.columns[i]}: {percentage:.2f}%")

print(f"\nTotal missing data in the dataset: {totalPercentage:.2f}%")
# Out:
# Percentage of missing data in the dataset:
# 	fuel_system: 0.78%
# 	fuel_consumption: 0.62%
# 	year_of_manufacture: 0.00%
# 	engine_capacity: 0.03%
# 	normalised_engine_capacity: 0.03%
# 	normalised_fuel_consumption: 0.62%
#
# Total missing data in the dataset: 2.09%

# %%
# Visualising the missing data
def colourize_bar(value, maxValue):
    low, high = maxValue * 0.2, maxValue * 0.66
    if(value <= low):
        return 'navajowhite'
    elif(value >= high):
        return 'darkorange'
    else:
        return 'orange'

cols = [colourize_bar(n, missing_data.max()) for n in missing_data]
total_data = [cleaned_car_data.shape[0]] * cleaned_car_data.shape[1]

plt.figure(figsize=(20,10))
plt.barh(cleaned_car_data.columns.values, total_data, color='aliceblue')
plt.barh(cleaned_car_data.columns.values, missing_data, color=cols)

plt.title('Visualising the Missing Values across the Dataset', size=20)
plt.xlabel('Missing Data vs. Existing', size=14)
plt.ylabel('Variable', size=14)

for index, value in enumerate(missing_data.values):
    plt.text(value + missing_data.max() * 0.01, index, str(value), va='center', ha='left', fontsize=12)

plt.show()

# %%
# Imputing missing values using RandomForest predictive modeling.
def impute_with_rf(df, target_col, categorical=False, excluded_cols=False):
    
    if excluded_cols is None:
        excluded_cols = []
    
    train = df[df[target_col].notna()]
    test = df[df[target_col].isna()]
    
    if test.empty:
        print(f"No missing values in '{target_col}'.")
        return df
    
    X_train = train.drop(columns=[target_col] + excluded_cols, errors='ignore')
    y_train = train[target_col]
    
    X_test = test.drop(columns=[target_col] + excluded_cols, errors='ignore')
    
    cat_cols = X_train.select_dtypes(include=['object']).columns
    num_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
    
    # Defining preprocessing for categorical and numerical data
    preprocessor = ColumnTransformer(
        transformers=[
            ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), cat_cols),
            ('num', StandardScaler(), num_cols)
        ])
    
    if categorical:
        model = RandomForestClassifier(random_state=101, n_jobs=-1)
    else:
        model = RandomForestRegressor(random_state=101, n_jobs=-1)
    
    # Create a pipeline
    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('model', model)
    ])
    
    pipeline.fit(X_train, y_train)
    
    predictions = pipeline.predict(X_test)
    
    # Assign the predicted values
    df.loc[df[target_col].isna(), target_col] = predictions
    
    return df

# %%
# List of variables with missing values and their types
imputation_order = [
    ('year_of_manufacture', False),
    ('engine_capacity', False),
    ('fuel_consumption', False),
    ('fuel_system', True)
]

# Remove derived variables before imputation
cleaned_car_data = cleaned_car_data.drop(
    columns=['normalised_engine_capacity', 'normalised_fuel_consumption'],
    errors='ignore'
)

# Track variables that originally had missing values
missing_vars = [name for name, is_categorical in imputation_order]
excluded_cols = missing_vars.copy()

for col, is_cat in imputation_order:
    print(f"Imputing '{col}'...")
    
    # Exclude variables that still contain missing values
    current_excluded = [var for var in excluded_cols if var != col]
    
    cleaned_car_data = impute_with_rf(
        cleaned_car_data,
        col, 
        categorical=is_cat,
        excluded_cols=current_excluded
    )
    
    # After imputation, remove the col from excluded_cols
    excluded_cols.remove(col)
    
    # Casting year to be an integer
    if col == 'year_of_manufacture':
        cleaned_car_data[col] = cleaned_car_data[col].astype(int)
    
    print(f"'{col}' completed.\n")


cleaned_car_data["normalised_engine_capacity"] = (cleaned_car_data["engine_capacity"] / cleaned_car_data["engine_capacity"].max())
cleaned_car_data["normalised_fuel_consumption"] = (cleaned_car_data["fuel_consumption"] / cleaned_car_data["fuel_consumption"].max())
# Out:
# Imputing 'year_of_manufacture'...
# 'year_of_manufacture' completed.
#
# Imputing 'engine_capacity'...
# 'engine_capacity' completed.
#
# Imputing 'fuel_consumption'...
# 'fuel_consumption' completed.
#
# Imputing 'fuel_system'...
# 'fuel_system' completed.

# %% [markdown]
# Missing values were handled using predictive imputation. A Random Forest model was trained using rows with known values for a given variable, and the trained model was then used to predict missing values. Numerical variables were imputed using a RandomForestRegressor, while categorical variables were imputed using a RandomForestClassifier. Derived variables such as normalized engine capacity were recalculated after imputation rather than being imputed directly to maintain consistency.

# %%
cleaned_car_data_missing_count = cleaned_car_data.isna().sum()
print("Missing values after predictive modeling:")
print(cleaned_car_data_missing_count.to_string())
# Out:
# Missing values after predictive modeling:
# ad_id                          0
# origin                         0
# condition                      0
# car_model                      0
# mileage                        0
# exterior_color                 0
# interior_color                 0
# num_of_doors                   0
# seating_capacity               0
# fuel_system                    0
# transmission                   0
# drive_type                     0
# fuel_consumption               0
# brand                          0
# grade                          0
# year_of_manufacture            0
# car_name                       0
# price (AUD)                    0
# type_of_engine                 0
# engine_capacity                0
# normalised_num_of_doors        0
# normalised_seating_capacity    0
# normalised_price (AUD)         0
# normalised_engine_capacity     0
# normalised_fuel_consumption    0

# %%
rows_before = processed_car_data.shape[0]
print(f"Before cleaning: {rows_before} rows")
print("\nMissing values before imputation:")
print(processed_car_data.isna().sum())
# Out:
# Before cleaning: 30652 rows
#
# Missing values before imputation:
# ad_id                              0
# origin                             0
# condition                          0
# car_model                          0
# mileage                            0
# exterior_color                     0
# interior_color                     0
# num_of_doors                       0
# seating_capacity                   0
# fuel_system                    23910
# transmission                       0
# drive_type                         0
# fuel_consumption               19216
# brand                              0
# grade                              0
# year_of_manufacture               32
# car_name                           0
# price (AUD)                        0
# type_of_engine                     0
# engine_capacity                 1367
# normalised_engine_capacity      1367
# normalised_num_of_doors            0
# normalised_seating_capacity        0
# normalised_fuel_consumption    19216
# normalised_price (AUD)             0
# dtype: int64

# %%
rows_after = cleaned_car_data.shape[0]
print(f"\nAfter cleaning: {rows_after} rows")
print("\nMissing values after imputation:")
print(cleaned_car_data.isna().sum())
# Out:
# After cleaning: 23959 rows
#
# Missing values after imputation:
# ad_id                          0
# origin                         0
# condition                      0
# car_model                      0
# mileage                        0
# exterior_color                 0
# interior_color                 0
# num_of_doors                   0
# seating_capacity               0
# fuel_system                    0
# transmission                   0
# drive_type                     0
# fuel_consumption               0
# brand                          0
# grade                          0
# year_of_manufacture            0
# car_name                       0
# price (AUD)                    0
# type_of_engine                 0
# engine_capacity                0
# normalised_num_of_doors        0
# normalised_seating_capacity    0
# normalised_price (AUD)         0
# normalised_engine_capacity     0
# normalised_fuel_consumption    0
# dtype: int64

# %%
# Save cleaned data to a new CSV file
cleaned_car_data.to_csv("cleaned_car_dataset.csv", index=False)

# %% [markdown]
# # 3. Data Storage

# %%
con = sqlite3.connect("carAdverts.db")
cur = con.cursor()

# %% [markdown]
# ## a. Creating Cars Table & b. Creating Sellers Table

# %%
fileNames = ["cleaned_car", "seller"]
fileStructures = {
    "Cars": {
        "ad_id": "ad_id INTEGER PRIMARY KEY",
        "car_name": "car_name VARCHAR(255)",
        "origin": "origin VARCHAR(255)",
        "condition": "condition VARCHAR(255)",
        "exterior_color": "exterior_color VARCHAR(255)",
        "car_model": "car_model VARCHAR(255)",
        "year_of_manufacture": "year_of_manufacture VARCHAR(255)",
        "transmission": "transmission VARCHAR(255)",
        "price": "price INTEGER",
        "drive_type": "drive_type VARCHAR(255)"
    },
    "Sellers": {
        "ad_id": "ad_id INTEGER PRIMARY KEY",
        "seller_name": "seller_name TEXT"
    }
}

tableNames = {
    "cleaned_car": "Cars",
    "seller": "Sellers"
}

# %%
def readCSV(csvName, fileStructure, tableName):
    ## READ CSV + HEADERS #
    with open(f"{csvName}_dataset.csv", "r") as csvFile:
        dictReader = csv.DictReader(csvFile)
        dictHeaders = dictReader.fieldnames # column names

        columnMapping = {
            "price (AUD)": "price",
            "name": "seller_name"
        }

        adjustedHeaders = [
            columnMapping.get(colName, colName) for colName in dictHeaders
        ]

        toInsert = [
            [dictRow.get(dictKey) for dictKey in dictHeaders if columnMapping.get(dictKey, dictKey) in fileStructure]
            for dictRow in dictReader
        ]
    ## READ CSV + HEADERS #

    ## CREATE TABLE ##
    cur.execute(f"DROP TABLE IF EXISTS {tableName};")

    insertColumns = []
    for colName in adjustedHeaders:
        if colName in fileStructure:
            insertColumns.append(fileStructure[colName])
    createString = ', '.join(insertColumns)

    sqlQuery = f"CREATE TABLE IF NOT EXISTS {tableName} ({createString});"
    cur.execute(sqlQuery)
    ## CREATE TABLE ##

    ## INSERT DATA ##
    insertHeaders = ", ".join([col for col in adjustedHeaders if col in fileStructure])
    insertValues = ", ".join("?" for _ in insertHeaders.split(", "))
    sqlQuery = f"INSERT INTO {tableName} ({insertHeaders}) VALUES ({insertValues});"
    cur.executemany(sqlQuery, toInsert)
    ## INSERT DATA ##

    print(f"Completed import for {tableName} with {len(cur.execute(f'SELECT * FROM {tableName}').fetchall())} rows...")


for fileName in fileNames:
    tableName = tableNames[fileName]
    fileStructure = fileStructures[tableName]
    readCSV(fileName, fileStructure, tableName)
# Out:
# Completed import for Cars with 23959 rows...
# Completed import for Sellers with 30652 rows...

# %% [markdown]
# ## c. Making the Query

# %%
sqlQuery = """
    SELECT
        Cars.ad_id,
        Cars.car_name,
        Cars.price,
        Sellers.seller_name
    FROM Cars
    LEFT OUTER JOIN Sellers ON Cars.ad_id = Sellers.ad_id;
"""

cur.execute(sqlQuery)
results = cur.fetchall()
for row in results:
    print(row)
# Out:
# (73954, 'Toyota Innova G 2.0 AT 2023 car', 35830.0393, 'Toyota - Brisbane')
# (74150, 'Toyota Corolla Cross 1.8G 2023', 30526.38376, 'Toyota - Perth')
# (87573, 'Toyota Innova G 2.0 AT 2022 car', 34413.03209, 'Toyota - Adelaide')
# (97011, 'Suzuki Super Carry Van Blind Van 2023', 12105.29011, 'Suzuki - Canberra')
# (101726, 'Honda CRV L 2023 car', 39838.14539, 'Honda - Darwin')
# (135739, 'Toyota Fortuner 2.7L 4x2 AT 2023', 40485.92011, 'Toyota - Hobart')
# (142495, 'Ford Ranger XLS 2.0L 4x2 AT 2023', 27854.31303, 'Ford - Gold Coast')
# (143308, 'Ford Ranger XLT 2.0L 4x4 AT 2023', 33603.31369, 'Ford - Newcastle')
# (174951, 'Ford Transit Ambulance 2023', 38056.76491, 'Ford - Wollongong')
# (182003, 'Toyota Innova E 2.0 MT 2022', 30364.44008, 'Toyota - Geelong')
# (183963, 'Toyota Vios E CVT 2022', 21943.3687, 'Toyota - Cairns')
# (203337, 'Ford Everest Ambiente 2.0L 4x2 AT 2023', 40485.92011, 'Ford - Toowoomba')
# (211394, 'Toyota Yaris G 1.5 AT 2022', 26315.84807, 'Toyota - Ballarat')
# (304604, 'Toyota Vios G 1.5 CVT 2022', 23967.66471, 'Toyota - Bendigo')
# (449343, 'Mitsubishi Outlander 2.0 CVT 2022', 33400.88409, 'Mitsubishi - Albury')
# (449349, 'Mitsubishi Xpander 1.5 MT 2022', 22469.68566, 'Mitsubishi - Launceston')
# (485640, 'Toyota Fortuner 2.4G 4x2 AT Legender 2022', 40485.92011, 'Toyota - Mackay')
# (485669, 'Toyota Innova E 2.0 MT 2022', 30566.86968, 'Toyota - Rockhampton')
# (485675, 'Toyota Innova E 2.0 MT 2022', 30566.86968, 'Toyota - Bundaberg')
# (694755, 'Honda City RS 1.5 AT 2023 car', 24251.06615, 'Honda - Alice Springs')
# (747206, 'Toyota Vios E 1.5 MT 2023', 19797.61493, 'Toyota - Kalgoorlie')
# (1126086, 'Toyota Innova Venturer 2.0 AT 2022', 35830.0393, 'Toyota - Tamworth')
# (1168135, 'Toyota Innova E 2.0 MT 2023', 28947.43288, 'Toyota - Orange')
# (1342730, 'Mercedes Benz C class C200 Avantgarde 2022', 40485.92011, 'Mercedes Benz - Adelaide')
# (1393396, 'Mazda 3 1.5L Premium 2023', 29716.66536, 'Mazda - Newcastle')
# (1393417, 'Mazda 3 1.5L Deluxe 2023', 24453.49575, 'Mazda - Wollongong')
# (1394005, 'Mazda 3 1.5L Sport Premium 2023', 29109.37656, 'Mazda - Geelong')
# (1429536, 'Hyundai Accent 1.4 MT 2023', 17206.51605, 'Hyundai - Townsville')
# (1429547, 'Hyundai SantaFe Premium 2.5L HTRAC 2023', 40485.92011, 'Hyundai - Cairns')
# (1429562, 'Hyundai Tucson 2.0 AT Standard 2022', 32064.84873, 'Hyundai - Toowoomba')
# (1429579, 'Hyundai Stargazer Special 1.5 AT 2022', 22186.28422, 'Hyundai - Ballarat')
# (1429653, 'Hyundai Creta Standard 1.5 AT 2022', 22955.5167, 'Hyundai - Bendigo')
# (1464997, 'Hyundai i10 1.2 AT 2023 car', 16639.71317, 'Hyundai - Albury')
# (1465025, 'Hyundai Elantra 1.6 AT Special 2022', 25101.27047, 'Hyundai - Launceston')
# (1465065, 'Hyundai SantaFe Premium 2.5L HTRAC 2023', 40485.92011, 'Hyundai - Mackay')
# (1465078, 'Hyundai Elantra N-Line 1.6 Turbo AT 2023', 31133.67257, 'Hyundai - Rockhampton')
# (1465099, 'Hyundai SantaFe Standard 2.5L 2023', 40485.92011, 'Hyundai - Bundaberg')
# (1465123, 'Hyundai i10 1.2 AT 2023 car', 16680.19909, 'Hyundai - Maitland')
# (1467840, 'Hyundai Stargazer Premium 1.5 AT 2022', 24493.98167, 'Hyundai - Burnie')
# (1519607, 'Hyundai Tucson 2.0 AT CRDi Special 2023', 40485.92011, 'Hyundai - Gladstone')
# (1580673, 'Hyundai Accent 1.4 AT Special 2023', 20728.79109, 'Hyundai - Kalgoorlie')
# (1599616, 'Toyota Innova 2.0G 2023 car', 35222.75049, 'Toyota - Devonport')
# (1625985, 'Toyota Innova G 2.0 AT 2023 car', 34008.17289, 'Toyota - Mandurah')
# (1660868, 'Honda CRV G 2023 car', 37368.50426, 'Honda - Tamworth')
# (1668465, 'Hyundai Creta Special 1.5 AT 2022', 25020.29863, 'Hyundai - Orange')
# (1733151, 'Toyota Innova Venturer 2.0 AT 2023', 35830.0393, 'Toyota - Dubbo')
# (1736820, 'Toyota Hilux 2.4L 4x2 AT 2023', 34494.00393, 'Toyota - Sydney')
# (1784799, 'Suzuki Ciaz 1.4 AT 2022 car', 21619.48134, 'Suzuki - Melbourne')
# (1807887, 'Mitsubishi Pajero Sport 2.4D 4x2 AT 2023', 40485.92011, 'Mitsubishi - Adelaide')
# (1875988, 'Hyundai Creta Special 1.5 AT 2022', 25020.29863, 'Hyundai - Canberra')
# (1876186, 'Hyundai Creta Special 1.5 AT 2022', 25020.29863, 'Hyundai - Darwin')
# (1876223, 'Hyundai Accent 1.4 AT 2023', 18744.98101, 'Hyundai - Hobart')
# (1876299, 'Hyundai Creta Premium 1.5 AT 2022', 28583.0596, 'Hyundai - Gold Coast')
# (1888442, 'Hyundai Tucson 2.0 AT Special 2023', 37570.93386, 'Hyundai - Newcastle')
# (1939983, 'Hyundai Accent 1.4 MT Standard 2023', 16396.79765, 'Hyundai - Wollongong')
# (1977257, 'Mercedes Benz GLC 200 2022', 40485.92011, 'Mercedes Benz - Geelong')
# (2001944, 'Suzuki Swift GLX 1.2 AT 2022 car', 22226.77014, 'Suzuki - Townsville')
# (2048368, 'Suzuki Swift GLX 2023 car', 22631.62934, 'Suzuki - Cairns')
# (2050181, 'Mazda 3 1.5L Sport Luxury 2023', 26680.22135, 'Mazda - Toowoomba')
# (2052733, 'Toyota Corolla altis 1.8G 2023', 29109.37656, 'Toyota - Ballarat')
# (2055450, 'Ford Everest Titanium Plus 2.0L 4x4 AT 2023', 40485.92011, 'Ford - Albury')
# (2056515, 'Toyota Wigo 1.2G MT 2023', 14251.04388, 'Toyota - Launceston')
# (2062513, 'Toyota Wigo 1.2G AT 2023 car', 15587.07924, 'Toyota - Mackay')
# (2112854, 'Mercedes Benz C class C200 Avantgarde Plus 2022', 40485.92011, 'Mercedes Benz - Bundaberg')
# (2142752, 'Toyota Vios E 1.5 MT 2023', 19797.61493, 'Toyota - Maitland')
# (2165805, 'Mazda CX5 2.0 Deluxe 2023 car', 30526.38376, 'Mazda - Burnie')
# (2261455, 'Audi Q7 S-line 3.6 AT 2009', 23481.83367, 'Audi - Hervey Bay')
# (2274966, 'Toyota Vios G 1.5 CVT 2023', 22105.31238, 'Toyota - Mount Gambier')
# (2301154, 'Ford Ranger Wildtrak 2.0L 4x4 AT 2023', 39352.31435, 'Ford - Kalgoorlie')
# (2301707, 'Ford Everest Titanium Plus 2.0L 4x4 AT 2023', 40485.92011, 'Ford - Mandurah')
# (2302095, 'Subaru Forester 2.0iS EyeSight 2022', 40445.43419, 'Subaru - Tamworth')
# (2314021, 'Ford Everest Titanium Plus 2.0L 4x4 AT 2023', 40485.92011, 'Ford - Orange')
# (2324881, 'Toyota Innova G 2.0 AT 2023 car', 35222.75049, 'Toyota - Dubbo')
# (2324982, 'Toyota Yaris G 1.5 AT 2023', 27692.36935, 'Toyota - Sydney')
# (2373043, 'Mazda CX5 2.0 Luxury 2023 car', 32145.82057, 'Mazda - Melbourne')
# (2417656, 'Honda Civic RS 1.5 AT 2023', 35425.18009, 'Honda - Brisbane')
# (2439373, 'Ford Ranger XL 2.0L 4x4 MT 2023', 26680.22135, 'Ford - Perth')
# (2446532, 'Ford Ranger XLS 2.0L 4x2 AT 2023', 27854.31303, 'Ford - Adelaide')
# (2446553, 'Ford Transit Van 940Kg 2023', 34372.54617, 'Ford - Canberra')
# (2450325, 'Hyundai Tucson 2.0 AT CRDi Special 2022', 40485.92011, 'Hyundai - Darwin')
# (2450364, 'Hyundai Accent 1.4 AT 2022', 18259.14997, 'Hyundai - Hobart')
# (2450413, 'Hyundai SantaFe Premium 2.2L HTRAC 2022', 40485.92011, 'Hyundai - Gold Coast')
# (2457664, 'Hyundai Accent 1.4 AT Special 2022', 19514.21349, 'Hyundai - Wollongong')
# (2457673, 'Hyundai Accent 1.4 MT Standard 2022', 16437.28357, 'Hyundai - Geelong')
# (2457693, 'Hyundai i10 1.2 AT 2023 car', 16801.65685, 'Hyundai - Townsville')
# (2457804, 'Hyundai i10 1.2 MT Standard 2022', 13481.8114, 'Hyundai - Cairns')
# (2486139, 'Suzuki Swift GLX 1.2 AT 2023 car', 22631.62934, 'Suzuki - Toowoomba')
# (2520901, 'Hyundai SantaFe Premium 2.2L HTRAC 2022', 40485.92011, 'Hyundai - Albury')
# (2538257, 'Suzuki Ertiga GL 1.5 MT 2022', 20202.47413, 'Suzuki - Launceston')
# (2544507, 'Hyundai Accent 1.4 AT Special 2022', 19514.21349, 'Hyundai - Mackay')
# (2545177, 'Hyundai Creta Standard 1.5 AT 2022', 23036.48854, 'Hyundai - Rockhampton')
# (2545232, 'Hyundai Tucson 2.0 AT Standard 2022', 31821.93321, 'Hyundai - Bundaberg')
# (2545268, 'Hyundai SantaFe Premium 2.5L HTRAC 2022', 40485.92011, 'Hyundai - Maitland')
# (2545274, 'Hyundai SantaFe Premium 2.5L HTRAC 2022', 40485.92011, 'Hyundai - Burnie')
# (2545864, 'Hyundai SantaFe Standard 2.5L 2022', 40485.92011, 'Hyundai - Bunbury')
# (2545890, 'Hyundai i10 1.2 AT 2023 car', 16153.88213, 'Hyundai - Gladstone')
# (2551314, 'Hyundai Tucson 2.0 AT Standard 2022', 31821.93321, 'Hyundai - Hervey Bay')
# (2559761, 'Kia Carnival Luxury 2.2D 2022', 40485.92011, 'Kia - Alice Springs')
# (2574165, 'Mazda CX8 Premium AWD 2022', 40485.92011, 'Mazda - Mandurah')
# (2575236, 'Toyota Fortuner 2.4G 4x2 MT 2022', 40485.92011, 'Toyota - Tamworth')
# (2597782, 'Mazda CX8 Luxury 2022 car', 40364.46235, 'Mazda - Orange')
# (2613860, 'Ford Everest Titanium Plus 2.0L 4x4 AT 2023', 40485.92011, 'Ford - Dubbo')
# (2613878, 'Ford Everest Sport 2.0L 4x2 AT 2023', 40485.92011, 'Ford - Sydney')
# (2613899, 'Ford Ranger XLT 2.0L 4x4 AT 2023', 33603.31369, 'Ford - Melbourne')
# (2613995, 'Ford Territory Titanium 1.5 AT 2023 car', 36801.70138, 'Ford - Brisbane')
# (2614057, 'Ford Ranger Wildtrak 2.0L 4x4 AT 2023', 39068.91291, 'Ford - Adelaide')
# (2614112, 'Ford Territory Titanium X 1.5 AT 2023', 38623.56779, 'Ford - Canberra')
# (2614182, 'Ford Ranger Raptor 2.0L 4x4 AT 2023', 40485.92011, 'Ford - Darwin')
# (2676458, 'Mazda CX5 Signature Premium 2.5 AT AWD I-Activ 2023', 38623.56779, 'Mazda - Hobart')
# (2681162, 'Suzuki Ertiga GL 1.5 MT 2022', 20202.47413, 'Suzuki - Gold Coast')
# (2720166, 'Ford Territory Titanium X 1.5 AT 2023', 38623.56779, 'Ford - Newcastle')
# (2751459, 'Toyota Fortuner 2.7L 4x2 AT 2022', 40485.92011, 'Toyota - Wollongong')
# (2769939, 'Mazda CX5 Deluxe 2.0 AT 2023 car', 30728.81337, 'Mazda - Geelong')
# (2772550, 'Mazda CX5 2.0 Deluxe 2022 car', 30728.81337, 'Mazda - Townsville')
# (2867693, 'Mitsubishi Triton 4x2 AT 2023', 26315.84807, 'Mitsubishi - Ballarat')
# (2906381, 'Mazda CX5 Premium 2.0 AT 2023 car', 33157.96857, 'Mazda - Bendigo')
# (2906419, 'Mazda CX5 Signature Premium 2.5 AT AWD I-Activ 2023', 38825.99739, 'Mazda - Albury')
# (2906554, 'Mazda CX5 2.0 Premium 2023 car', 33157.96857, 'Mazda - Launceston')
# (2906562, 'Mazda CX5 Luxury 2.0 AT 2023 car', 32348.25017, 'Mazda - Mackay')
# (2928467, 'Mazda 3 1.5L Sport Premium 2023', 28906.94696, 'Mazda - Rockhampton')
# (2930139, 'Mitsubishi Triton 4x2 AT 2023', 26315.84807, 'Mitsubishi - Bundaberg')
# (2963299, 'Mazda 2 Sport Luxury 2023 car', 20931.2207, 'Mazda - Maitland')
# (2971738, 'Ford Ranger XLS 2.0L 4x2 AT 2023', 27854.31303, 'Ford - Burnie')
# (2978446, 'Ford Ranger XLT 2.0L 4x4 AT 2023', 31983.87689, 'Ford - Bunbury')
# (2986873, 'Toyota Fortuner 2.4L 4x2 AT 2022', 40485.92011, 'Toyota - Gladstone')
# (3019216, 'Toyota Vios G 1.5 CVT 2023', 23967.66471, 'Toyota - Alice Springs')
# (3035229, 'Mazda 3 1.5L Deluxe 2023', 24251.06615, 'Mazda - Kalgoorlie')
# (3080407, 'Ford Ranger Raptor 2.0L 4x4 AT 2023', 40485.92011, 'Ford - Devonport')
# (3080432, 'Ford Ranger XLT 2.0L 4x4 AT 2023', 31579.01769, 'Ford - Mandurah')
# (3080452, 'Ford Ranger XLS 2.0L 4x2 AT 2023', 25425.15783, 'Ford - Tamworth')
# (3080537, 'Ford Ranger Wildtrak 2.0L 4x4 AT 2023', 37651.9057, 'Ford - Orange')
# (3120496, 'Ford Ranger XLS 2.0L 4x2 AT 2023', 27854.31303, 'Ford - Melbourne')
# (3121163, 'Toyota Fortuner 2.4G 4x2 AT 2022', 40485.92011, 'Toyota - Brisbane')
# (3121183, 'Toyota Fortuner 2.4G 4x2 MT 2022', 40485.92011, 'Toyota - Perth')
# (3130018, 'Mitsubishi Attrage 1.2 CVT 2022', 18825.95285, 'Mitsubishi - Adelaide')
# (3136657, 'Mazda CX5 2.0 Premium 2022 car', 33157.96857, 'Mazda - Canberra')
# (3140118, 'Mitsubishi Attrage 1.2 MT 2022', 15384.64964, 'Mitsubishi - Darwin')
# (3155495, 'Toyota Vios 1.5E 2016', 12591.12115, 'Toyota - Newcastle')
# (3157424, 'Mazda 2 Sport Luxury 2023 car', 20931.2207, 'Mazda - Wollongong')
# (3164466, 'Mazda CX5 Premium 2.0 AT 2023 car', 33157.96857, 'Mazda - Geelong')
# (3164470, 'Mazda CX5 Deluxe 2.0 AT 2023 car', 30728.81337, 'Mazda - Townsville')
# (3164574, 'Mazda CX5 Luxury 2.0 AT 2023 car', 32348.25017, 'Mazda - Cairns')
# (3167410, 'Mercedes Benz GLC 200 2022', 40485.92011, 'Mercedes Benz - Toowoomba')
# (3175737, 'Ford Everest Titanium 2.0L 4x2 AT 2023', 40485.92011, 'Ford - Ballarat')
# (3177271, 'Ford Ranger XLS 2.2L 4x2 AT 2022', 26032.44663, 'Ford - Bendigo')
# (3177628, 'Ford Ranger XL 2.0L 4x4 MT 2022', 25060.78455, 'Ford - Albury')
# (3182786, 'Toyota Avanza 1.5 AT 2023', 22186.28422, 'Toyota - Launceston')
# (3184510, 'Mitsubishi Attrage 1.2 CVT 2023', 18825.95285, 'Mitsubishi - Mackay')
# (3184524, 'Mitsubishi Attrage 1.2 MT 2023', 15384.64964, 'Mitsubishi - Rockhampton')
# (3192117, 'Suzuki XL7 1.5 AT 2023 car', 24251.06615, 'Suzuki - Bundaberg')
# (3193673, 'Ford Everest Titanium Plus 2.0L 4x4 AT 2022', 40485.92011, 'Ford - Maitland')
# (3197114, 'Mercedes Benz S class S350 2006', 21659.96726, 'Mercedes Benz - Burnie')
# (3201559, 'Suzuki XL7 1.5 AT 2022 car', 24251.06615, 'Suzuki - Bunbury')
# (3207222, 'BMW 7 Series 730Li M Sport 2022', 11295.57171, 'BMW - Hervey Bay')
# (3208256, 'Mazda 2 1.5 AT 2022', 17044.57237, 'Mazda - Mount Gambier')
# (3215510, 'Ford Ranger XL 2.0L 4x4 MT 2023', 25060.78455, 'Ford - Devonport')
# (3251329, 'Mazda 2 Luxury 2023 car', 20445.38965, 'Mazda - Mandurah')
# (3251335, 'Mazda 2 Sport Luxury 2023 car', 20931.2207, 'Mazda - Tamworth')
# (3268410, 'Mitsubishi Xpander 1.5 AT 2022', 23805.72103, 'Mitsubishi - Orange')
# (3271281, 'Mitsubishi Triton 4x2 AT 2022', 26315.84807, 'Mitsubishi - Dubbo')
# (3271310, 'Mitsubishi Attrage 1.2 CVT 2022', 18825.95285, 'Mitsubishi - Sydney')
# (3276494, 'Ford Transit Van 2022', 34008.17289, 'Ford - Melbourne')
# (3280671, 'VinFast Lux A 2.0 Standard 2022 car', 31538.53177, 'VinFast - Brisbane')
# (3287097, 'Mitsubishi Attrage 1.2 CVT 2022', 18825.95285, 'Mitsubishi - Perth')
# (3306671, 'VinFast Lux SA 2.0 Premium 2022 Car', 40485.92011, 'VinFast - Adelaide')
# (3306675, 'VinFast Lux A 2.0 Standard 2022 car', 31538.53177, 'VinFast - Canberra')
# (3307074, 'VinFast Lux A 2.0 Advanced 2022 car', 35263.23641, 'VinFast - Darwin')
# (3320389, 'Toyota Innova G 2.0 AT 2023 car', 35222.75049, 'Toyota - Hobart')
# (3325652, 'Honda Accord 1.5 AT 2022', 40485.92011, 'Honda - Gold Coast')
# (3325689, 'Honda City RS 1.5 AT 2022 car', 24251.06615, 'Honda - Newcastle')
# (3325692, 'Honda City L 1.5 AT 2022 car', 22631.62934, 'Honda - Wollongong')
# (3325698, 'Honda CRV E 2022 car', 40404.94827, 'Honda - Geelong')
# (3325701, 'Honda CRV G 2022 car', 40485.92011, 'Honda - Townsville')
# (3325702, 'Honda CRV L 2022 car', 40485.92011, 'Honda - Cairns')
# (3346972, 'Mitsubishi Xpander Premium 1.5 AT 2022', 26234.87623, 'Mitsubishi - Toowoomba')
# (3347016, 'Mitsubishi Xpander Premium 1.5 AT 2022', 26234.87623, 'Mitsubishi - Ballarat')
# (3347422, 'Mazda CX5 2.0 Luxury 2022 car', 32348.25017, 'Mazda - Bendigo')
# (3353959, 'Mitsubishi Attrage 1.2 CVT 2023', 18623.52325, 'Mitsubishi - Albury')
# (3354016, 'Toyota Wigo 1.2 AT 2023 car', 15546.59332, 'Toyota - Launceston')
# (3355108, 'Mitsubishi Attrage 1.2 MT 2022', 15384.64964, 'Mitsubishi - Mackay')
# (3355127, 'Mitsubishi Attrage 1.2 CVT 2022', 18825.95285, 'Mitsubishi - Rockhampton')
# (3355148, 'Mitsubishi Xpander Premium 1.5 AT 2022', 26234.87623, 'Mitsubishi - Bundaberg')
# (3357176, 'Honda City G 1.5 AT 2022 car', 21417.05174, 'Honda - Maitland')
# (3357423, 'Mitsubishi Triton 4x2 AT Mivec 2023', 26315.84807, 'Mitsubishi - Burnie')
# (3357466, 'Mitsubishi Attrage 1.2 MT 2023', 15182.22004, 'Mitsubishi - Bunbury')
# (3357935, 'Kia Seltos Deluxe 1.4 AT 2023', 25182.24231, 'Kia - Gladstone')
# (3358156, 'Honda CRV L 2023 car', 40485.92011, 'Honda - Hervey Bay')
# (3358166, 'Honda CRV E 2023 car', 40404.94827, 'Honda - Alice Springs')
# (3362608, 'Toyota Innova Venturer 2.0 AT 2023', 34210.60249, 'Toyota - Mount Gambier')
# (3363636, 'Toyota Corolla Cross 1.8HV 2023', 37894.82122, 'Toyota - Kalgoorlie')
# (3366136, 'Mazda 6 Luxury 2.0 AT 2023', 31943.39097, 'Mazda - Devonport')
# (3366155, 'Mazda 2 1.5 AT 2023', 17247.00197, 'Mazda - Mandurah')
# (3366344, 'Toyota Corolla Cross 1.8V 2023', 34817.89129, 'Toyota - Tamworth')
# (3367311, 'Toyota Corolla Cross 1.8V 2023', 34251.08841, 'Toyota - Orange')
# (3367980, 'Toyota Corolla Cross 1.8V 2023', 34251.08841, 'Toyota - Dubbo')
# (3367997, 'Toyota Corolla Cross 1.8V 2022', 34817.89129, 'Toyota - Sydney')
# (3371285, 'Volkswagen Polo 1.6 AT 2022', 28137.71448, 'Volkswagen - Melbourne')
# (3371316, 'Volkswagen Polo 1.6 AT 2022', 28137.71448, 'Volkswagen - Brisbane')
# (3371409, 'Volkswagen Polo 1.6 AT 2022', 28137.71448, 'Volkswagen - Perth')
# (3371546, 'Toyota Corolla Cross 1.8V 2023', 34251.08841, 'Toyota - Adelaide')
# (3371620, 'Toyota Corolla Cross 1.8HV 2023', 38664.05371, 'Toyota - Canberra')
# (3371646, 'Toyota Fortuner 2.4G 4x2 AT Legender 2023', 40485.92011, 'Toyota - Darwin')
# (3372188, 'Volkswagen Tiguan Luxury S 2022', 40485.92011, 'Volkswagen - Hobart')
# (3375986, 'Volkswagen Tiguan Luxury S 2022', 40485.92011, 'Volkswagen - Gold Coast')
# (3376232, 'Toyota Corolla Cross 1.8V 2023', 34251.08841, 'Toyota - Newcastle')
# (3376236, 'Toyota Corolla Cross 1.8V 2023', 34251.08841, 'Toyota - Wollongong')
# (3376361, 'Toyota Corolla Cross 1.8V 2023', 34817.89129, 'Toyota - Geelong')
# (3377992, 'Suzuki XL7 1.5 AT 2022 car', 21862.39686, 'Suzuki - Townsville')
# (3378087, 'Honda CRV G 2023 car', 40485.92011, 'Honda - Cairns')
# (3379690, 'Toyota Corolla Cross 1.8V 2023', 34251.08841, 'Toyota - Toowoomba')
# (3380462, 'Mazda CX5 2.0 Premium 2023 car', 32955.53897, 'Mazda - Ballarat')
# (3381200, 'Toyota Corolla Cross 1.8V 2023', 32834.08121, 'Toyota - Bendigo')
# (3381250, 'Mazda 3 1.5L Luxury 2022', 24858.35495, 'Mazda - Albury')
# (3381284, 'Mazda CX5 Deluxe 2.0 AT 2022 car', 30526.38376, 'Mazda - Launceston')
# (3382863, 'Toyota Corolla Cross 1.8V 2023', 34251.08841, 'Toyota - Mackay')
# (3387469, 'Toyota Corolla Cross 1.8V 2022', 34251.08841, 'Toyota - Rockhampton')
# (3403849, 'VinFast Lux A 2.0 Standard 2022 car', 35668.09562, 'VinFast - Maitland')
# (3413223, 'Honda CRV L 2022 car', 40485.92011, 'Honda - Burnie')
# (3413400, 'Honda CRV G 2022 car', 40485.92011, 'Honda - Bunbury')
# (3414491, 'Honda CRV L 2022 car', 40485.92011, 'Honda - Gladstone')
# (3416430, 'Mazda 2 Luxury 2022 car', 19838.10085, 'Mazda - Hervey Bay')
# (3416611, 'Mazda CX5 Premium 2.0 AT 2022 car', 33157.96857, 'Mazda - Alice Springs')
# (3416677, 'Suzuki XL7 1.5 AT 2022 car', 24251.06615, 'Suzuki - Mount Gambier')
# (3421219, 'Mitsubishi Outlander 2.0 CVT 2023', 33400.88409, 'Mitsubishi - Kalgoorlie')
# (3421232, 'Mitsubishi Outlander Premium 2.0 CVT 2023', 38461.62411, 'Mitsubishi - Devonport')
# (3421305, 'Kia Sorento Luxury 2.2 AT 2022', 40485.92011, 'Kia - Mandurah')
# (3425742, 'Toyota Fortuner 2.4L 4x2 MT 2023', 40485.92011, 'Toyota - Tamworth')
# (3426086, 'Toyota Fortuner 2.4G 4x2 AT 2023', 40485.92011, 'Toyota - Orange')
# (3426269, 'Toyota Fortuner 2.4G 4x2 MT 2023', 40485.92011, 'Toyota - Dubbo')
# (3427048, 'Toyota Fortuner 2.4G 4x2 AT 2023', 40485.92011, 'Toyota - Sydney')
# (3427131, 'Toyota Fortuner 2.4G 4x2 AT 2023', 40485.92011, 'Toyota - Melbourne')
# (3433619, 'Ford Ranger Wildtrak 2.0L 4x4 AT 2023', 39352.31435, 'Ford - Brisbane')
# (3433628, 'Ford Ranger Wildtrak 2.0L 4x4 AT 2023', 39068.91291, 'Ford - Perth')
# (3433652, 'Ford Everest Sport 2.0L 4x2 AT 2023', 40485.92011, 'Ford - Adelaide')
# (3433664, 'Ford Everest Titanium 2.0L 4x2 AT 2023', 40485.92011, 'Ford - Canberra')
# (3435400, 'Ford Everest Ambiente 2.0L 4x2 AT 2023', 40485.92011, 'Ford - Hobart')
# (3435455, 'Ford Ranger XLS 2.0L 4x4 AT 2023', 30607.35561, 'Ford - Gold Coast')
# (3435509, 'Ford Transit Van 2023', 34372.54617, 'Ford - Newcastle')
# (3437056, 'Kia Sorento Luxury 2.2 AT 2022', 40485.92011, 'Kia - Wollongong')
# (3437087, 'Ford Everest Sport 2.0L 4x2 AT 2023', 40485.92011, 'Ford - Geelong')
# (3437511, 'Suzuki XL7 1.5 AT 2022 car', 24251.06615, 'Suzuki - Townsville')
# (3438943, 'Toyota Fortuner 2.4G 4x2 AT 2023', 40485.92011, 'Toyota - Cairns')
# (3439275, 'Toyota Fortuner 2.4L 4x2 AT 2022', 40485.92011, 'Toyota - Toowoomba')
# (3439560, 'Toyota Corolla Cross 1.8HV 2023', 37894.82122, 'Toyota - Ballarat')
# (3444032, 'Kia Sorento Signature 2.2 AT AWD 2023', 40485.92011, 'Kia - Bendigo')
# (3444039, 'Kia Seltos Deluxe 1.4 AT 2023', 26680.22135, 'Kia - Albury')
# (3445465, 'Suzuki Swift GLX 1.2 AT 2023 car', 22631.62934, 'Suzuki - Launceston')
# (3453700, 'Suzuki Ciaz 1.4 AT 2022 car', 21619.48134, 'Suzuki - Mackay')
# (3454956, 'Toyota Fortuner 2.4G 4x2 MT 2023', 40485.92011, 'Toyota - Rockhampton')
# (3454961, 'Toyota Fortuner 2.4G 4x2 AT 2023', 40485.92011, 'Toyota - Bundaberg')
# (3455197, 'VinFast Lux SA 2.0 Advanced 2022 car', 40485.92011, 'VinFast - Maitland')
# (3455236, 'VinFast Lux SA 2.0 Standard 2022 car', 40485.92011, 'VinFast - Burnie')
# (3455350, 'VinFast Lux A 2.0 Premium 2022 Car', 40485.92011, 'VinFast - Bunbury')
# (3456044, 'Toyota Fortuner 2.4G 4x2 AT Legender 2023', 40485.92011, 'Toyota - Gladstone')
# (3456110, 'Mitsubishi Triton 4x2 AT 2022', 26315.84807, 'Mitsubishi - Hervey Bay')
# (3456397, 'Mitsubishi Pajero Sport 2.4D 4x2 AT 2022', 40485.92011, 'Mitsubishi - Alice Springs')
# (3457160, 'Mitsubishi Pajero Sport 2.4D 4x4 AT 2022', 40485.92011, 'Mitsubishi - Mount Gambier')
# (3457898, 'Toyota Yaris G 1.5 AT 2023', 27692.36935, 'Toyota - Kalgoorlie')
# (3458011, 'Mazda 3 1.5L Deluxe 2022', 24453.49575, 'Mazda - Devonport')
# (3458033, 'Mazda 3 1.5L Luxury 2022', 25546.61559, 'Mazda - Mandurah')
# (3461905, 'Mazda CX5 2.0 Luxury 2023 car', 32145.82057, 'Mazda - Tamworth')
# (3463170, 'Toyota Innova E 2.0 MT 2023', 30566.86968, 'Toyota - Orange')
# (3465752, 'Toyota Yaris G 1.5 AT 2023', 27692.36935, 'Toyota - Dubbo')
# (3467748, 'Mitsubishi Pajero Sport 2.4D 4x2 AT 2022', 40485.92011, 'Mitsubishi - Sydney')
# (3468107, 'Toyota Innova G 2.0 AT 2023 car', 35222.75049, 'Toyota - Melbourne')
# (3468115, 'Toyota Fortuner 2.8V 4x4 AT Legender 2023', 19028.38245, 'Toyota - Brisbane')
# (3468141, 'Toyota Corolla Cross 1.8V 2023', 34817.89129, 'Toyota - Perth')
# (3468614, 'Kia Sorento Signature 2.2 AT AWD 2023', 40485.92011, 'Kia - Adelaide')
# (3469002, 'Mazda 3 1.5L Deluxe 2023', 25465.64375, 'Mazda - Canberra')
# (3469279, 'Mazda 2 Sport Luxury 2023 car', 20931.2207, 'Mazda - Darwin')
# (3472556, 'Toyota Innova 2.0E 2016 car', 14898.8186, 'Toyota - Hobart')
# (3473414, 'VinFast Lux A 2.0 Standard 2022 car', 35668.09562, 'VinFast - Gold Coast')
# (3473431, 'VinFast Lux A 2.0 Standard 2022 car', 35668.09562, 'VinFast - Newcastle')
# (3473483, 'VinFast Lux A 2.0 Premium 2022 Car', 40485.92011, 'VinFast - Wollongong')
# (3473647, 'Toyota Innova E 2.0 MT 2023', 30566.86968, 'Toyota - Geelong')
# (3483764, 'Mitsubishi Triton 4x2 AT 2022', 26315.84807, 'Mitsubishi - Cairns')
# (3489346, 'Toyota Innova E 2.0 MT 2023', 30566.86968, 'Toyota - Toowoomba')
# (3490801, 'Toyota Fortuner Legender 2.4L 4x2 AT 2022', 40485.92011, 'Toyota - Ballarat')
# (3490814, 'Toyota Corolla Cross 1.8HV 2022', 38664.05371, 'Toyota - Bendigo')
# (3490818, 'Toyota Vios E CVT 2023', 21943.3687, 'Toyota - Albury')
# (3491696, 'Toyota Yaris G 1.5 AT 2023', 27044.59463, 'Toyota - Launceston')
# (3496078, 'Toyota Innova E 2.0 MT 2022', 30566.86968, 'Toyota - Mackay')
# (3496083, 'Toyota Yaris G 1.5 AT 2023', 27692.36935, 'Toyota - Rockhampton')
# (3502739, 'Mitsubishi Outlander Premium 2.0 CVT 2022', 38461.62411, 'Mitsubishi - Bundaberg')
# (3503169, 'Toyota Innova E 2.0 MT 2022', 30566.86968, 'Toyota - Maitland')
# (3503220, 'Toyota Fortuner 2.4L 4x2 AT 2023', 40485.92011, 'Toyota - Burnie')
# (3503240, 'Honda Accord 1.5 AT 2023', 40485.92011, 'Honda - Bunbury')
# (3503318, 'Toyota Innova G 2.0 AT 2023 car', 35222.75049, 'Toyota - Gladstone')
# (3503797, 'Toyota Fortuner Legender 2.4L 4x2 AT 2022', 40485.92011, 'Toyota - Hervey Bay')
# (3505042, 'Toyota Yaris G 1.5 AT 2023', 27692.36935, 'Toyota - Alice Springs')
# (3505258, 'Toyota Innova G 2.0 AT 2023 car', 35222.75049, 'Toyota - Mount Gambier')
# (3505365, 'Toyota Yaris G 1.5 AT 2023', 27692.36935, 'Toyota - Kalgoorlie')
# (3505373, 'Toyota Fortuner 2.4G 4x2 MT 2023', 40485.92011, 'Toyota - Devonport')
# (3505381, 'Toyota Fortuner 2.4G 4x2 AT 2023', 40485.92011, 'Toyota - Mandurah')
# (3505396, 'Toyota Innova G 2.0 AT 2023 car', 35222.75049, 'Toyota - Tamworth')
# (3505410, 'Toyota Innova E 2.0 MT 2023', 30566.86968, 'Toyota - Orange')
# (3513805, 'Mitsubishi Xpander 1.5 MT 2023', 22469.68566, 'Mitsubishi - Sydney')
# (3513847, 'Toyota Hilux 2.8L 4x4 AT 2022', 36963.64506, 'Toyota - Melbourne')
# (3518405, 'Peugeot 3008 AL 2023', 40485.92011, 'Peugeot - Brisbane')
# (3518482, 'Peugeot 3008 AL 2023', 40485.92011, 'Peugeot - Perth')
# (3518555, 'Peugeot 3008 AL 2023', 40485.92011, 'Peugeot - Adelaide')
# (3518565, 'Peugeot 3008 AL 2023', 40485.92011, 'Peugeot - Canberra')
# (3518570, 'Peugeot 3008 AL 2023', 40485.92011, 'Peugeot - Darwin')
# (3518582, 'Peugeot 3008 AL 2023', 40485.92011, 'Peugeot - Hobart')
# (3518786, 'Peugeot 3008 GT 2023', 40485.92011, 'Peugeot - Gold Coast')
# (3518829, 'Peugeot 5008 AL 1.6 AT 2023', 40485.92011, 'Peugeot - Newcastle')
# (3518841, 'Peugeot 5008 AL 1.6 AT 2023', 40485.92011, 'Peugeot - Wollongong')
# (3518849, 'Peugeot 5008 AL 1.6 AT 2023', 40485.92011, 'Peugeot - Geelong')
# (3518859, 'Peugeot 5008 GT 1.6 AT 2023', 40485.92011, 'Peugeot - Townsville')
# (3518983, 'Peugeot 3008 AL 2023', 40485.92011, 'Peugeot - Cairns')
# (3520124, 'Kia Morning X-Line 2022 car', 17773.31893, 'Kia - Toowoomba')
# (3526696, 'Kia Morning GT-Line 2022', 17975.74853, 'Kia - Ballarat')
# (3528023, 'Mazda CX5 Deluxe 2022 car', 30728.81337, 'Mazda - Bendigo')
# (3528457, 'Mazda CX8 Luxury 2022 car', 40445.43419, 'Mazda - Albury')
# (3528460, 'Mazda 3 1.5L Premium 2022', 29919.09496, 'Mazda - Launceston')
# (3537684, 'Ford Everest Sport 2.0L 4x2 AT 2023', 40485.92011, 'Ford - Mackay')
# (3538484, 'Toyota Yaris G 1.5 AT 2023', 27692.36935, 'Toyota - Rockhampton')
# (3547275, 'Hyundai Accent 1.4 AT Special 2023', 20242.96005, 'Hyundai - Bundaberg')
# (3551716, 'Hyundai Accent 1.4 AT Special 2023', 21255.10806, 'Hyundai - Maitland')
# (3557645, 'Hyundai Accent 1.4 AT Special 2022', 19757.12901, 'Hyundai - Burnie')
# (3557649, 'Hyundai Accent 1.4 AT 2022', 18664.00917, 'Hyundai - Bunbury')
# (3566434, 'Toyota Prado TXL 2.7L 2013', 40485.92011, 'Toyota - Gladstone')
# (3567373, 'Peugeot 2008 GT Line 1.2 AT 2023', 34372.54617, 'Peugeot - Hervey Bay')
# (3567376, 'Peugeot 2008 Active 1.2 AT 2023', 31538.53177, 'Peugeot - Alice Springs')
# (3572225, 'Mitsubishi Attrage 1.2 CVT 2022', 18825.95285, 'Mitsubishi - Mount Gambier')
# (3572898, 'Honda City RS 1.5 AT 2023 car', 24251.06615, 'Honda - Kalgoorlie')
# (3572903, 'Honda City L 1.5 AT 2023 car', 23036.48854, 'Honda - Devonport')
# (3572992, 'Honda City RS 1.5 AT 2023 car', 24251.06615, 'Honda - Mandurah')
# (3573431, 'Mitsubishi Outlander Premium 2.0 CVT 2022', 38461.62411, 'Mitsubishi - Tamworth')
# (3574932, 'Toyota Corolla Cross 1.8V 2022', 34574.97577, 'Toyota - Orange')
# (3582166, 'Mitsubishi Pajero Sport 2.4D 4x2 AT 2022', 40485.92011, 'Mitsubishi - Dubbo')
# (3582167, 'Mitsubishi Pajero Sport 2.4D 4x4 AT 2022', 40485.92011, 'Mitsubishi - Sydney')
# (3583263, 'Hyundai Accent 1.4 AT Special 2022', 22064.82646, 'Hyundai - Brisbane')
# (3592384, 'Hyundai Accent 1.4 AT Special 2022', 20647.81925, 'Hyundai - Canberra')
# (3594918, 'Hyundai Accent 1.4 AT Special 2023', 20566.84741, 'Hyundai - Darwin')
# (3594924, 'Hyundai Accent 1.4 AT 2023', 18947.41061, 'Hyundai - Hobart')
# (3609880, 'Toyota Innova Venturer 2.0 AT 2023', 35830.0393, 'Toyota - Gold Coast')
# (3618938, 'Suzuki Ertiga Hybrid 1.5 MT 2022', 20728.79109, 'Suzuki - Newcastle')
# (3620633, 'MG ZS Luxury 1.5 AT 2WD 2022', 24615.43943, 'MG - Wollongong')
# (3623320, 'MG ZS Standard 1.5 AT 2WD 2022', 20647.81925, 'MG - Geelong')
# (3624211, 'Toyota Innova G 2.0 AT 2023 car', 34008.17289, 'Toyota - Townsville')
# (3624230, 'Toyota Corolla Cross 1.8V 2023', 34817.89129, 'Toyota - Cairns')
# (3624263, 'Toyota Fortuner 2.4L 4x2 AT 2022', 40485.92011, 'Toyota - Toowoomba')
# (3626733, 'Honda CRV L 2023 car', 40485.92011, 'Honda - Ballarat')
# (3628652, 'Mercedes Benz GLC 200 4Matic 2019', 40485.92011, 'Mercedes Benz - Bendigo')
# (3630395, 'Mazda 3 1.5L Sport Premium 2022', 29109.37656, 'Mazda - Albury')
# (3640995, 'Toyota Fortuner 2.4G 4x2 AT 2023', 40485.92011, 'Toyota - Launceston')
# (3640998, 'Toyota Corolla Cross 1.8V 2022', 32348.25017, 'Toyota - Mackay')
# (3641011, 'Toyota Vios G 1.5 CVT 2023', 23157.9463, 'Toyota - Rockhampton')
# (3642114, 'Mitsubishi Triton 4x2 AT 2022', 26315.84807, 'Mitsubishi - Bundaberg')
# (3650985, 'Honda CRV 2.0 AT 2011', 17732.83301, 'Honda - Burnie')
# (3651121, 'Acura MDX SH-AWD 2009', 22874.54486, 'Acura - Bunbury')
# (3675593, 'Mitsubishi Attrage Premium 1.2 CVT 2022', 19838.10085, 'Mitsubishi - Gladstone')
# (3677305, 'Toyota Vios G 1.5 CVT 2022', 23967.66471, 'Toyota - Hervey Bay')
# (3680120, 'Isuzu Dmax Type Z 1.9L 4x4 AT 2023', 33603.31369, 'Isuzu - Alice Springs')
# (3681048, 'Toyota Vios G 1.5 CVT 2023', 23967.66471, 'Toyota - Mount Gambier')
# (3681105, 'Mitsubishi Attrage Premium 1.2 CVT 2022', 19838.10085, 'Mitsubishi - Kalgoorlie')
# (3681578, 'Toyota Vios G 1.5 CVT 2023', 21538.5095, 'Toyota - Devonport')
# (3681920, 'Toyota Vios G 1.5 CVT 2022', 23967.66471, 'Toyota - Mandurah')
# (3681923, 'Toyota Vios E 1.5 MT 2022', 19797.61493, 'Toyota - Tamworth')
# (3682788, 'Toyota Vios G 1.5 CVT 2023', 23967.66471, 'Toyota - Brisbane')
# (3682795, 'Toyota Vios E CVT 2023', 21943.3687, 'Toyota - Perth')
# (3683319, 'Toyota Vios E 1.5 MT 2023', 19797.61493, 'Toyota - Adelaide')
# (3683670, 'Honda City RS 1.5 AT 2023 car', 24453.49575, 'Honda - Hobart')
# (3684476, 'Kia Soluto 1.4 MT Deluxe 2022', 16639.71317, 'Kia - Gold Coast')
# (3684812, 'Toyota Vios G 1.5 CVT 2023', 23724.74919, 'Toyota - Newcastle')
# (3687534, 'Mitsubishi Attrage Premium 1.2 CVT 2022', 19635.67125, 'Mitsubishi - Wollongong')
# (3687692, 'Peugeot 2008 GT Line 1.2 AT 2023', 34372.54617, 'Peugeot - Geelong')
# (3687700, 'Peugeot 2008 Active 1.2 AT 2023', 31538.53177, 'Peugeot - Townsville')
# (3687942, 'Toyota Corolla Cross 1.8HV 2023', 37894.82122, 'Toyota - Cairns')
# (3688157, 'Toyota Vios G 1.5 CVT 2023', 23967.66471, 'Toyota - Toowoomba')
# (3688923, 'Toyota Vios GR-S 1.5 CVT 2023', 25506.12967, 'Toyota - Ballarat')
# (3689402, 'Toyota Vios E 1.5 MT 2023', 17975.74853, 'Toyota - Bendigo')
# (3690061, 'Mitsubishi Attrage Premium 1.2 CVT 2022', 19838.10085, 'Mitsubishi - Launceston')
# (3691498, 'Mitsubishi Attrage Premium 1.2 CVT 2022', 19838.10085, 'Mitsubishi - Mackay')
# (3691928, 'Mazda CX5 Luxury 2.0 AT 2023 car', 35587.12378, 'Mazda - Rockhampton')
# (3691998, 'Mazda 2 Sport Luxury 2023 car', 23238.91815, 'Mazda - Bundaberg')
# (3693357, 'Toyota Vios E CVT 2023', 21943.3687, 'Toyota - Maitland')
# (3694659, 'Toyota Vios E 1.5 MT 2023', 19554.69941, 'Toyota - Burnie')
# (3699592, 'Toyota Vios G 1.5 CVT 2023', 23076.97446, 'Toyota - Bunbury')
# (3699978, 'Toyota Vios E 1.5 MT 2023', 18987.89653, 'Toyota - Gladstone')
# (3701545, 'Toyota Vios G 1.5 CVT 2023', 23562.80551, 'Toyota - Hervey Bay')
# (3706887, 'Subaru Forester 2.0iL 2023', 38785.51147, 'Subaru - Alice Springs')
# (3707275, 'Toyota Vios 1.5G 2019', 21659.96726, 'Toyota - Mount Gambier')
# (3707672, 'Mercedes Benz GLC 200 2022', 40485.92011, 'Mercedes Benz - Devonport')
# (3713624, 'Ford Everest Titanium Plus 2.0L 4x4 AT 2023', 40485.92011, 'Ford - Tamworth')
# (3715650, 'Maserati Quattroporte S Q4 3.0 V6 2013', 32388.73609, 'Maserati - Orange')
# (3719645, 'Toyota Innova E 2.0 MT 2022', 30566.86968, 'Toyota - Dubbo')
# (3719651, 'Toyota Yaris G 1.5 AT 2022', 27692.36935, 'Toyota - Sydney')
# (3719653, 'Toyota Corolla Cross 1.8V 2022', 34251.08841, 'Toyota - Melbourne')
# (3719654, 'Toyota Fortuner 2.4G 4x2 MT 2022', 40485.92011, 'Toyota - Brisbane')
# (3719655, 'Toyota Fortuner 2.4G 4x2 MT 2022', 40485.92011, 'Toyota - Perth')
# (3719657, 'Toyota Fortuner 2.4G 4x2 AT 2022', 40485.92011, 'Toyota - Adelaide')
# (3719662, 'Toyota Corolla Cross 1.8HV 2022', 37894.82122, 'Toyota - Canberra')
# (3719826, 'Toyota Vios E 1.5 MT 2022', 19797.61493, 'Toyota - Darwin')
# (3719837, 'Toyota Vios E CVT 2022', 21943.3687, 'Toyota - Hobart')
# (3719850, 'Toyota Vios G 1.5 CVT 2022', 23967.66471, 'Toyota - Gold Coast')
# (3724681, 'Honda City L 1.5 AT 2023 car', 23036.48854, 'Honda - Newcastle')
# (3726516, 'Hyundai Accent 1.4 AT Special 2022', 19514.21349, 'Hyundai - Wollongong')
# (3726544, 'Hyundai Accent 1.4 AT 2023', 19028.38245, 'Hyundai - Geelong')
# (3726553, 'Hyundai Accent 1.4 AT Special 2023', 20647.81925, 'Hyundai - Townsville')
# (3729824, 'Hyundai Accent 1.4 AT 2023', 19595.18533, 'Hyundai - Albury')
# (3730173, 'Toyota Fortuner 2.4G 4x2 AT 2023', 40485.92011, 'Toyota - Launceston')
# (3736861, 'Toyota Vios E CVT 2023', 21943.3687, 'Toyota - Bundaberg')
# (3736867, 'Toyota Vios E 1.5 MT 2023', 19797.61493, 'Toyota - Maitland')
# (3737692, 'Hyundai Accent 1.4 AT 2022', 19230.81205, 'Hyundai - Burnie')
# (3752080, 'Mitsubishi Attrage Premium 1.2 CVT 2022', 19838.10085, 'Mitsubishi - Kalgoorlie')
# (3752088, 'Mitsubishi Attrage 1.2 MT 2022', 15020.27636, 'Mitsubishi - Devonport')
# (3753464, 'Honda City L 1.5 AT 2023 car', 23036.48854, 'Honda - Mandurah')
# (3754244, 'Toyota Vios E CVT 2023', 21700.45318, 'Toyota - Tamworth')
# (3754251, 'Toyota Vios E 1.5 MT 2023', 19554.69941, 'Toyota - Orange')
# (3754258, 'Toyota Vios GR-S 1.5 CVT 2023', 25708.55927, 'Toyota - Dubbo')
# (3754261, 'Toyota Camry 2.0G 2023', 40485.92011, 'Toyota - Sydney')
# (3755308, 'Honda City L 1.5 AT 2023 car', 23036.48854, 'Honda - Melbourne')
# (3761807, 'Toyota Vios E 1.5 MT 2023', 18583.03733, 'Toyota - Brisbane')
# (3761850, 'Chevrolet Cruze LTZ 1.8 AT 2016', 16801.65685, 'Chevrolet - Perth')
# (3761858, 'Toyota Vios G 1.5 CVT 2023', 22753.0871, 'Toyota - Adelaide')
# (3761916, 'Toyota Corolla Cross 1.8V 2022', 33036.51081, 'Toyota - Canberra')
# (3762356, 'Honda CRV G 2023 car', 37368.50426, 'Honda - Darwin')
# (3762394, 'Honda City RS 1.5 AT 2023 car', 21619.48134, 'Honda - Hobart')
# (3765518, 'Toyota Vios E 1.5 MT 2023', 19797.61493, 'Toyota - Wollongong')
# (3772177, 'Isuzu Dmax LS 1.9L 4x2 AT 2023', 26720.70727, 'Isuzu - Geelong')
# (3774713, 'Mazda 6 Signature Premium 2.5 AT 2023', 37692.39162, 'Mazda - Toowoomba')
# (3777237, 'Mazda cx3 Luxury 1.5 AT 2023 car', 27894.79895, 'Mazda - Ballarat')
# (3777247, 'Mazda CX 30 Luxury 2.0 AT 2023', 34372.54617, 'Mazda - Bendigo')
# (3777633, 'Mazda cx3 Luxury 1.5 AT 2022 car', 24615.43943, 'Mazda - Albury')
# (3777698, 'Mazda cx3 Luxury 1.5 AT 2023 car', 25101.27047, 'Mazda - Launceston')
# (3777702, 'Mazda CX 30 Luxury 2.0 AT 2023', 30931.24297, 'Mazda - Mackay')
# (3785218, 'Mercedes Benz GLC 200 2021', 40485.92011, 'Mercedes Benz - Bundaberg')
# (3785593, 'Chevrolet Cruze LTZ 1.8L 2017', 18421.09365, 'Chevrolet - Maitland')
# (3789809, 'Mazda cx3 1.5L Premium 2023 car', 26761.19319, 'Mazda - Gladstone')
# (3796588, 'VinFast VF e34 2022 car', 20040.53045, 'VinFast - Hervey Bay')
# (3797835, 'Hyundai Accent 1.4 AT 2023', 18825.95285, 'Hyundai - Alice Springs')
# (3798561, 'Honda CRV L 2023 car', 39676.20171, 'Honda - Mount Gambier')
# (3802114, 'Mazda cx3 Premium 1.5 AT 2023 car', 26963.62279, 'Mazda - Kalgoorlie')
# (3802120, 'Mazda CX 30 Luxury 2.0 AT 2023', 30931.24297, 'Mazda - Devonport')
# (3802141, 'Mazda 3 1.5L Premium 2023', 29919.09496, 'Mazda - Mandurah')
# (3802148, 'Mazda 3 1.5L Deluxe 2023', 26275.36215, 'Mazda - Tamworth')
# (3802151, 'Mazda 3 1.5L Luxury 2023', 25546.61559, 'Mazda - Orange')
# (3814334, 'Mercedes Benz GLC 200 2021', 40485.92011, 'Mercedes Benz - Dubbo')
# (3815218, 'Chevrolet Colorado LTZ 2.8L 4x4 AT 2015', 19392.75573, 'Chevrolet - Melbourne')
# (3816060, 'Toyota Corolla Cross 1.8V 2022', 32348.25017, 'Toyota - Brisbane')
# (3818967, 'Hyundai SantaFe Premium 2.5L HTRAC 2023', 40485.92011, 'Hyundai - Perth')
# (3818998, 'Hyundai SantaFe Premium 2.2L HTRAC 2022', 40485.92011, 'Hyundai - Adelaide')
# (3819374, 'Isuzu Dmax LS 1.9L 4x2 MT 2023', 23481.83367, 'Isuzu - Canberra')
# (3819388, 'Isuzu Dmax LS 1.9L 4x2 MT 2023', 23481.83367, 'Isuzu - Darwin')
# (3819391, 'Isuzu Dmax LS 1.9L 4x2 MT 2023', 23481.83367, 'Isuzu - Hobart')
# (3819394, 'Isuzu Dmax LS 1.9L 4x2 AT 2023', 24696.41127, 'Isuzu - Gold Coast')
# (3819398, 'Isuzu Dmax LS 1.9L 4x2 AT 2023', 24696.41127, 'Isuzu - Newcastle')
# (3819401, 'Isuzu Dmax LS 1.9L 4x2 MT 2023', 23481.83367, 'Isuzu - Wollongong')
# (3819420, 'Isuzu Dmax LS 1.9L 4x2 AT 2023', 24696.41127, 'Isuzu - Geelong')
# (3820899, 'Hyundai SantaFe Premium 2.2L HTRAC 2023', 40485.92011, 'Hyundai - Bendigo')
# (3822117, 'Kia Sorento Signature 2.5 AT AWD 2022', 40485.92011, 'Kia - Albury')
# (3822240, 'Toyota Fortuner 2.4G 4x2 AT Legender 2023', 40485.92011, 'Toyota - Launceston')
# (3822295, 'Toyota Corolla Cross 1.8V 2023', 34817.89129, 'Toyota - Mackay')
# (3822337, 'Toyota Corolla Cross 1.8G 2023', 30566.86968, 'Toyota - Rockhampton')
# (3822389, 'Kia Seltos Premium 1.4 AT 2022', 29716.66536, 'Kia - Bundaberg')
# (3822392, 'Toyota Corolla Cross 1.8HV 2023', 38664.05371, 'Toyota - Maitland')
# (3823212, 'Hyundai SantaFe Standard 2.2L 2022', 40485.92011, 'Hyundai - Burnie')
# (3823219, 'Hyundai SantaFe Standard 2.5L 2022', 40485.92011, 'Hyundai - Bunbury')
# (3823225, 'Hyundai SantaFe Premium 2.5L HTRAC 2022', 40485.92011, 'Hyundai - Gladstone')
# (3823229, 'Hyundai SantaFe Premium 2.2L HTRAC 2022', 40485.92011, 'Hyundai - Hervey Bay')
# (3824025, 'Hyundai Elantra 2.0 AT 2017', 23076.97446, 'Hyundai - Alice Springs')
# (3826416, 'Toyota Vios E 1.5 MT 2023', 19797.61493, 'Toyota - Mount Gambier')
# (3826421, 'Toyota Vios E CVT 2023', 21943.3687, 'Toyota - Kalgoorlie')
# (3826678, 'Hyundai SantaFe Standard 2.2L 2023', 40485.92011, 'Hyundai - Devonport')
# (3826685, 'Hyundai SantaFe Standard 2.5L 2023', 40485.92011, 'Hyundai - Mandurah')
# (3826727, 'Hyundai SantaFe Premium 2.2L HTRAC 2023', 40485.92011, 'Hyundai - Tamworth')
# (3826732, 'Hyundai SantaFe Premium 2.5L HTRAC 2023', 40485.92011, 'Hyundai - Orange')
# (3830888, 'Hyundai Accent 1.4 AT Special 2023', 20445.38965, 'Hyundai - Dubbo')
# (3834100, 'Kia Cerato 1.6 AT 2018', 22672.11526, 'Kia - Sydney')
# (3842113, 'Hyundai SantaFe Premium 2.5L HTRAC 2023', 40485.92011, 'Hyundai - Melbourne')
# (3842139, 'Hyundai SantaFe Premium 2.2L HTRAC 2023', 11578.97315, 'Hyundai - Brisbane')
# (3846487, 'Toyota Corolla Cross 1.8HV 2022', 37894.82122, 'Toyota - Perth')
# (3847899, 'Mitsubishi Triton Athlete 4x2 AT 2022', 31012.21481, 'Mitsubishi - Adelaide')
# (3855673, 'Mercedes Benz GLC 200 2022', 40485.92011, 'Mercedes Benz - Darwin')
# (3858612, 'Kia Rondo GAT 2016 car', 19028.38245, 'Kia - Wollongong')
# (3861032, 'Mazda CX 30 Premium 2.0 AT 2023', 31457.55993, 'Mazda - Geelong')
# (3861037, 'Mazda cx3 Luxury 1.5 AT 2023 car', 25101.27047, 'Mazda - Townsville')
# (3861045, 'Mazda CX 30 Luxury 2.0 AT 2023', 30323.95416, 'Mazda - Cairns')
# (3869821, 'Toyota Corolla Cross 1.8V 2022', 33441.37001, 'Toyota - Ballarat')
# (3871466, 'Toyota Vios 1.5E 2015', 12064.80419, 'Toyota - Bendigo')
# (3876591, 'Mazda CX5 Premium 2.0 AT 2023 car', 32955.53897, 'Mazda - Albury')
# (3877379, 'Volvo XC40 B5 AWD Ultimate 2022', 40485.92011, 'Volvo - Mackay')
# (3878753, 'Mitsubishi Triton 4x2 AT 2022', 24089.12247, 'Mitsubishi - Rockhampton')
# (3882601, 'Toyota Vios E CVT 2022', 20728.79109, 'Toyota - Maitland')
# (3882609, 'Hyundai Accent 1.4 MT 2019', 18016.23445, 'Hyundai - Burnie')
# (3883117, 'Hyundai SantaFe Premium 2.5L HTRAC 2022', 40485.92011, 'Hyundai - Bunbury')
# (3885863, 'Mitsubishi Triton 4x2 AT 2022', 24089.12247, 'Mitsubishi - Gladstone')
# (3888444, 'Ford Ranger Wildtrak 3.2L 4x4 AT 2016', 28299.65816, 'Ford - Hervey Bay')
# (3890538, 'Mazda 3 1.5L Luxury 2022', 27287.51015, 'Mazda - Alice Springs')
# (3892342, 'Mitsubishi Pajero Sport 2.4D 4x4 AT 2023', 40485.92011, 'Mitsubishi - Mount Gambier')
# (3893224, 'Mitsubishi Attrage Premium 1.2 CVT 2022', 19838.10085, 'Mitsubishi - Kalgoorlie')
# (3894439, 'Cadillac STS 3.6 AT 2008', 23846.20695, 'Cadillac - Devonport')
# (3895945, 'Hyundai SantaFe Premium 2.2L HTRAC 2023', 40485.92011, 'Hyundai - Mandurah')
# (3901474, 'Mitsubishi Pajero Sport 2.4D 4x4 AT 2023', 40485.92011, 'Mitsubishi - Orange')
# (3903828, 'Mitsubishi Triton 4x2 AT Mivec 2023', 24089.12247, 'Mitsubishi - Dubbo')
# (3904056, 'Hyundai SantaFe Premium 2.2L HTRAC 2023', 40485.92011, 'Hyundai - Sydney')
# (3904530, 'Hyundai SantaFe Standard 2.2L 2023', 40485.92011, 'Hyundai - Melbourne')
# (3912665, 'Mercedes Benz GLB 200 AMG 2023', 40485.92011, 'Mercedes Benz - Perth')
# (3914959, 'Kia Morning GT-Line 2022', 19190.32613, 'Kia - Adelaide')
# (3915038, 'Kia Sorento Signature 2.2 AT AWD 2022', 40485.92011, 'Kia - Canberra')
# (3916626, 'Isuzu Dmax LS 1.9L 4x2 MT 2023', 23481.83367, 'Isuzu - Darwin')
# (3922698, 'Hyundai Accent 1.4 AT Special 2023', 20081.01637, 'Hyundai - Hobart')
# (3922965, 'Hyundai Accent 1.4 AT 2023', 18866.43877, 'Hyundai - Gold Coast')
# (3923015, 'Audi A6 2.0T 2010', 22267.25606, 'Audi - Newcastle')
# (3923229, 'Hyundai SantaFe Premium 2.5L HTRAC 2023', 40485.92011, 'Hyundai - Wollongong')
# (3923601, 'BMW X4 xDrive20i 2018', 40485.92011, 'BMW - Geelong')
# (3936869, 'Hyundai Elantra 1.6 MT 2017', 16315.82581, 'Hyundai - Townsville')
# (3941360, 'Toyota Innova E 2.0 MT 2023', 30566.86968, 'Toyota - Ballarat')
# (3942296, 'Hyundai i10 1.2 AT 2023 car', 16680.19909, 'Hyundai - Bendigo')
# (3942595, 'Hyundai i10 1.2 AT 2023 car', 16396.79765, 'Hyundai - Albury')
# (3946038, 'Toyota Fortuner 2.4L 4x2 AT 2022', 40485.92011, 'Toyota - Launceston')
# (3946140, 'Hyundai i10 1.2 AT 2023 car', 16396.79765, 'Hyundai - Mackay')
# (3946178, 'Hyundai i10 1.2 AT 2022 car', 16720.68501, 'Hyundai - Rockhampton')
# (3946183, 'Hyundai i10 1.2 AT 2022 car', 16720.68501, 'Hyundai - Bundaberg')
# (3946896, 'Chrysler 300C 2.7 Limited 2009', 21457.53766, 'Chrysler - Maitland')
# (3947006, 'Hyundai i10 1.2 AT 2022 car', 16396.79765, 'Hyundai - Burnie')
# (3947534, 'Ford Transit Ambulance 2022', 38461.62411, 'Ford - Bunbury')
# (3951152, 'Hyundai Accent 1.4 AT 2023', 18947.41061, 'Hyundai - Hervey Bay')
# (3951177, 'Hyundai SantaFe Premium 2.2L HTRAC 2023', 40485.92011, 'Hyundai - Alice Springs')
# (3951185, 'Hyundai SantaFe Premium 2.5L HTRAC 2023', 40485.92011, 'Hyundai - Mount Gambier')
# (3954447, 'Subaru Forester 2.0iS EyeSight GT Edition 2022', 40485.92011, 'Subaru - Devonport')
# (3965100, 'Mazda 2 Luxury 2023 car', 21740.9391, 'Mazda - Tamworth')
# (3966675, 'Mazda cx3 Luxury 1.5 AT 2023 car', 25101.27047, 'Mazda - Orange')
# (3967551, 'Mazda 3 1.5L Sport Premium 2023', 30728.81337, 'Mazda - Sydney')
# (3967810, 'Mazda 6 Signature Premium 2.5 AT 2023', 40445.43419, 'Mazda - Melbourne')
# (3967820, 'Mazda 3 1.5L Deluxe 2023', 26275.36215, 'Mazda - Brisbane')
# (3967837, 'Mazda 3 1.5L Luxury 2023', 27287.51015, 'Mazda - Perth')
# (3967852, 'Mazda CX5 Premium 2.0 AT 2023 car', 34777.40537, 'Mazda - Adelaide')
# (3967996, 'Mazda CX 30 Luxury 2.0 AT 2023', 30931.24297, 'Mazda - Canberra')
# (3968002, 'Mazda cx3 Premium 1.5 AT 2023 car', 26963.62279, 'Mazda - Darwin')
# (3977837, 'BMW 3 Series 328i 2013', 22267.25606, 'BMW - Gold Coast')
# (3978946, 'Volvo XC40 Ultimate 2022 car', 40485.92011, 'Volvo - Newcastle')
# (3978949, 'Volvo XC40 Ultimate 2022 car', 40485.92011, 'Volvo - Wollongong')
# (3981881, 'Hyundai i10 1.2 AT 2023 car', 16518.25541, 'Hyundai - Geelong')
# (3982258, 'Mercedes Benz CLS class CLS 300 2010', 26113.41847, 'Mercedes Benz - Townsville')
# (3982351, 'Nissan Murano SL 3.5 AWD 2005', 13562.78324, 'Nissan - Cairns')
# (3998642, 'Hyundai i10 1.2 AT 2023 car', 15749.02292, 'Hyundai - Launceston')
# (4000304, 'Volkswagen Tiguan Allspace Luxury S 2019', 40485.92011, 'Volkswagen - Mackay')
# (4004193, 'Hyundai i10 1.2 AT 2023 car', 16680.19909, 'Hyundai - Maitland')
# (4005861, 'Hyundai SantaFe Premium 2.5L HTRAC 2023', 40485.92011, 'Hyundai - Bunbury')
# (4006257, 'Honda City G 1.5 AT 2023 car', 20647.81925, 'Honda - Gladstone')
# (4007143, 'Hyundai i10 1.2 AT 2022 car', 17611.37525, 'Hyundai - Hervey Bay')
# (4007253, 'Honda City G 1.5 AT 2023 car', 21417.05174, 'Honda - Alice Springs')
# (4015946, 'Kia K3 Premium 1.6 AT 2022 car', 28704.51736, 'Kia - Orange')
# (4016080, 'Mercedes Benz GLC 200 4Matic 2021', 35627.6097, 'Mercedes Benz - Dubbo')
# (4016403, 'Hyundai Accent 1.4 AT Special 2023', 20566.84741, 'Hyundai - Sydney')
# (4016580, 'Hyundai SantaFe Standard 2.2L 2023', 40485.92011, 'Hyundai - Melbourne')
# (4016627, 'Mercedes Benz GLC 200 2022', 40485.92011, 'Mercedes Benz - Brisbane')
# (4018125, 'Hyundai SantaFe Standard 2.2L 2023', 40485.92011, 'Hyundai - Perth')
# (4018159, 'Hyundai Accent 1.4 MT 2023', 18016.23445, 'Hyundai - Adelaide')
# (4018194, 'Hyundai Accent 1.4 AT Special 2023', 20566.84741, 'Hyundai - Canberra')
# (4020123, 'Kia K3 Premium 1.6 AT 2022 car', 26477.79175, 'Kia - Darwin')
# (4021354, 'Kia Seltos Premium 1.4 AT 2022', 30728.81337, 'Kia - Hobart')
# (4022567, 'Mercedes Benz GLC 200 2021', 40485.92011, 'Mercedes Benz - Toowoomba')
# (4023263, 'Kia K3 Premium 1.6 AT 2023 car', 28704.51736, 'Kia - Albury')
# (4023610, 'Kia K3 Premium 1.6 AT 2022 car', 27085.08055, 'Kia - Mackay')
# (4023613, 'Kia K3 Premium 1.6 AT 2022 car', 27085.08055, 'Kia - Rockhampton')
# (4023616, 'Kia Carnival Luxury 2.2D 2022', 40485.92011, 'Kia - Bundaberg')
# (4025612, 'Mercedes Benz C class C180 AMG 2021', 40485.92011, 'Mercedes Benz - Gladstone')
# (4027245, 'Kia Carnival Luxury 2.2D 2022', 40485.92011, 'Kia - Alice Springs')
# (4027264, 'Kia Sonet Luxury 1.5 AT 2023', 23643.77735, 'Kia - Mount Gambier')
# (4027269, 'Kia K3 Premium 1.6 AT 2023 car', 26477.79175, 'Kia - Kalgoorlie')
# (4027325, 'Kia Carnival Premium 2.2D 2022', 40485.92011, 'Kia - Devonport')
# (4027404, 'Mazda CX5 Deluxe 2.0 AT 2023 car', 30526.38376, 'Mazda - Mandurah')
# (4028084, 'Kia Carnival Luxury 2.2D 2023', 40485.92011, 'Kia - Tamworth')
# (4028088, 'Kia Carnival Premium 2.2D 8S 2023', 40485.92011, 'Kia - Orange')
# (4028092, 'Kia Carnival Signature 3.5G 2023', 40485.92011, 'Kia - Dubbo')
# (4028833, 'Mercedes Benz E class E250 2014', 28947.43288, 'Mercedes Benz - Sydney')
# (4029457, 'Toyota Fortuner 2.4G 4x2 AT Legender 2022', 40485.92011, 'Toyota - Melbourne')
# (4029471, 'Toyota Corolla Cross 1.8HV 2022', 36234.8985, 'Toyota - Brisbane')
# (4029629, 'Mercedes Benz GLC 300 4Matic 2019', 40485.92011, 'Mercedes Benz - Perth')
# (4031375, 'Kia K5 Luxury 2.0 AT 2022 car', 34777.40537, 'Kia - Adelaide')
# (4031399, 'Kia Sonet Premium 1.5 AT 2022 car', 24048.63655, 'Kia - Canberra')
# (4032723, 'Hyundai Accent 1.4 AT Special 2023', 20647.81925, 'Hyundai - Darwin')
# (4032831, 'Toyota Fortuner 2.4G 4x2 AT 2022', 40485.92011, 'Toyota - Hobart')
# (4032856, 'Hyundai Accent 1.4 AT 2023', 19028.38245, 'Hyundai - Gold Coast')
# (4033959, 'Hyundai SantaFe Premium 2.2L HTRAC 2023', 40485.92011, 'Hyundai - Newcastle')
# (4034158, 'Hyundai i10 1.2 AT 2022 car', 17125.54421, 'Hyundai - Wollongong')
# (4034663, 'Kia K3 Premium 1.6 AT 2023 car', 25830.01703, 'Kia - Geelong')
# (4035138, 'Hyundai Accent 1.4 MT Standard 2023', 16437.28357, 'Hyundai - Townsville')
# (4037215, 'Mercedes Benz C class C300 AMG 2020', 40485.92011, 'Mercedes Benz - Cairns')
# (4038752, 'Mercedes Benz C class C200 Exclusive 2019', 40485.92011, 'Mercedes Benz - Toowoomba')
# (4041800, 'Kia K5 Luxury 2.0 AT 2022 car', 35789.55338, 'Kia - Bendigo')
# (4041803, 'Kia Sonet Premium 1.5 AT 2022 car', 24048.63655, 'Kia - Albury')
# (4042052, 'Mazda BT50 Premium 1.9L 4x4 AT 2022', 34372.54617, 'Mazda - Launceston')
# (4042063, 'Mazda cx3 Luxury 1.5 AT 2023 car', 25101.27047, 'Mazda - Mackay')
# (4042073, 'Mazda CX 30 Premium 2.0 AT 2023', 32955.53897, 'Mazda - Rockhampton')
# (4042174, 'Mazda 2 Luxury 2023 car', 20809.76294, 'Mazda - Bundaberg')
# (4042182, 'Mazda CX5 Deluxe 2.0 AT 2023 car', 30728.81337, 'Mazda - Maitland')
# (4044123, 'Hyundai Accent 1.4 AT 2023', 18947.41061, 'Hyundai - Bunbury')
# (4044251, 'Mercedes Benz GLC 300 4Matic 2019', 40485.92011, 'Mercedes Benz - Gladstone')
# (4048280, 'Hyundai Avante 1.6 MT 2012', 11538.48723, 'Hyundai - Hervey Bay')
# (4050199, 'Kia Carnival Signature 3.5G 2023', 40485.92011, 'Kia - Mount Gambier')
# (4052245, 'Toyota Raize G 1.0 CVT 2023', 22145.7983, 'Toyota - Kalgoorlie')
# (4055170, 'Mitsubishi Pajero Sport 2.4D 4x4 AT 2022', 40485.92011, 'Mitsubishi - Orange')
# (4057394, 'Hyundai Accent 1.4 AT 2022', 18744.98101, 'Hyundai - Sydney')
# (4057466, 'Hyundai SantaFe Premium 2.5L HTRAC 2022', 40485.92011, 'Hyundai - Melbourne')
# (4057474, 'Hyundai SantaFe Standard 2.5L 2022', 4.05e-05, 'Hyundai - Brisbane')
# (4057479, 'Hyundai SantaFe Standard 2.2L 2022', 40485.92011, 'Hyundai - Perth')
# (4057496, 'Hyundai i10 1.2 AT 2022 car', 16599.22725, 'Hyundai - Adelaide')
# (4057502, 'Hyundai i10 1.2 MT 2022 car', 14979.79044, 'Hyundai - Canberra')
# (4057507, 'Hyundai i10 1.2 AT 2022 car', 18016.23445, 'Hyundai - Darwin')
# (4063628, 'Mazda CX5 Deluxe 2.0 AT 2023 car', 30728.81337, 'Mazda - Newcastle')
# (4064626, 'Toyota Corolla Cross 1.8V 2022', 34251.08841, 'Toyota - Wollongong')
# (4064640, 'Toyota Corolla Cross 1.8V 2022', 34251.08841, 'Toyota - Geelong')
# (4068178, 'Toyota Innova 2.0E 2016 car', 14574.93124, 'Toyota - Townsville')
# ...
# (4929300, 'VinFast Lux A 2.0 2.0 AT 2020 car', 25708.55927, 'VinFast - Darwin')
# (4929301, 'Daewoo Matiz SE 0.8 MT 2005', 1538.464964, 'Daewoo - Hobart')
# (4929304, 'Mazda 6 2.0 AT 2014', 17773.31893, 'Mazda - Gold Coast')
# (4929305, 'Hyundai i10 1.2 2018 car', 14372.50164, 'Hyundai - Newcastle')
# (4929306, 'Hyundai Tucson 2.0L 2022', 36032.4689, 'Hyundai - Wollongong')
# (4929307, 'Nissan Almera VL 1.0 CVT Premium 2023', 22064.82646, 'Nissan - Geelong')
# (4929312, 'Mazda cx3 1.5 Luxury 2022 car', 25060.78455, 'Mazda - Townsville')
# (4929316, 'Honda City L 2021 car', 19433.24165, 'Honda - Cairns')
# (4929317, 'Nissan Almera VL 1.0 CVT Premium 2023', 22064.82646, 'Nissan - Toowoomba')
# (4929318, 'Nissan Almera VL 1.0 CVT Premium 2023', 22064.82646, 'Nissan - Ballarat')
# (4929319, 'Toyota Vios 2020 car', 14979.79044, 'Toyota - Bendigo')
# (4929323, 'Chevrolet Colorado LTZ 2.5L 4x4 AT 2019', 21659.96726, 'Chevrolet - Albury')
# (4929325, 'Nissan Almera EL 1.0 CVT 2023', 19757.12901, 'Nissan - Mackay')
# (4929326, 'Nissan Almera EL 1.0 CVT 2023', 19757.12901, 'Nissan - Rockhampton')
# (4929329, 'Toyota Rush 1.5AT 2019', 21376.56582, 'Toyota - Bundaberg')
# (4929330, 'Ford Ranger XLS 2.2AT 2020', 24251.06615, 'Ford - Maitland')
# (4929335, 'Nissan Almera EL 1.0 CVT 2023', 19757.12901, 'Nissan - Bunbury')
# (4929338, 'Nissan Almera EL 1.0 CVT 2023', 19757.12901, 'Nissan - Gladstone')
# (4929339, 'Mazda CX5 2.0 Luxury 2020 car', 29959.58088, 'Mazda - Hervey Bay')
# (4929344, 'Toyota Innova 2.0E 2015 car', 16599.22725, 'Toyota - Kalgoorlie')
# (4929345, 'Nissan Navara Pro-4X 2.3 AT 4WD 2023', 34008.17289, 'Nissan - Devonport')
# (4929348, 'Toyota Rush 1.5AT 2020', 24696.41127, 'Toyota - Mandurah')
# (4929349, 'Nissan Navara Pro-4X 2.3 AT 4WD 2023', 34008.17289, 'Nissan - Tamworth')
# (4929353, 'Nissan Navara Pro-4X 2.3 AT 4WD 2023', 34008.17289, 'Nissan - Dubbo')
# (4929355, 'Toyota Camry 2.0G 2019', 33927.20105, 'Toyota - Sydney')
# (4929358, 'Mazda 6 Luxury 2.0 2019', 26356.33399, 'Mazda - Melbourne')
# (4929362, 'BMW 3 Series F30 2015', 27530.42567, 'BMW - Brisbane')
# (4929363, 'Nissan Navara VL 2.3 AT 4WD 2023', 32996.02489, 'Nissan - Perth')
# (4929369, 'Mazda CX8 LUXURY 2022 car', 40445.43419, 'Mazda - Adelaide')
# (4929370, 'Kia Morning 2016 car', 9271.275707, 'Kia - Canberra')
# (4929371, 'Nissan Navara EL 2.3 AT 2WD 2023', 25870.50295, 'Nissan - Darwin')
# (4929375, 'Nissan Navara EL 2.3 AT 2WD 2023', 25870.50295, 'Nissan - Gold Coast')
# (4929376, 'Nissan Navara EL 2.3 AT 2WD 2023', 25870.50295, 'Nissan - Newcastle')
# (4929379, 'VinFast Fadil PREMIUM 2020 car', 13279.38179, 'VinFast - Wollongong')
# (4929380, 'Toyota Fortuner 2.7V 4x2 AT 2013', 19230.81205, 'Toyota - Geelong')
# (4929382, 'Ford Ranger XLS 2.0L 4x2 2023', 27854.31303, 'Ford - Cairns')
# (4929384, 'Hyundai Tucson 2.0 ATH 2017', 27085.08055, 'Hyundai - Ballarat')
# (4929388, 'Nissan Kicks e-Power E 2023 car', 29514.23576, 'Nissan - Bendigo')
# (4929392, 'VinFast VF8 Plus 2022 car', 37854.3353, 'VinFast - Launceston')
# (4929393, 'Mazda CX8 PREMIUM 2022 car', 40485.92011, 'Mazda - Mackay')
# (4929394, 'Mazda 2 2019 car', 17408.94565, 'Mazda - Rockhampton')
# (4929395, 'Nissan Kicks e-Power V 2023', 31659.98953, 'Nissan - Bundaberg')
# (4929400, 'Mercedes Benz E class E200 Sport 2019', 40485.92011, 'Mercedes Benz - Maitland')
# (4929401, 'Ford Ranger XLS 2.0L MT 4x2 2023', 26923.13687, 'Ford - Burnie')
# (4929404, 'Nissan Kicks e-Power V 2023', 31659.98953, 'Nissan - Bunbury')
# (4929405, 'Chevrolet Lacetti 2010', 6396.775377, 'Chevrolet - Gladstone')
# (4929409, 'Mercedes Benz GLC 250 4Matic 2016', 40485.92011, 'Mercedes Benz - Alice Springs')
# (4929414, 'Nissan Kicks e-Power V 2023', 31659.98953, 'Nissan - Kalgoorlie')
# (4929415, 'Toyota Corolla Cross 1.8HV 2022', 37854.3353, 'Toyota - Devonport')
# (4929416, 'Mercedes Benz GLC 200 2020', 40485.92011, 'Mercedes Benz - Mandurah')
# (4929420, 'Toyota RAV4 2006', 13157.92403, 'Toyota - Tamworth')
# (4929424, 'Mazda CX8 PREMUM AWD 2022', 40485.92011, 'Mazda - Orange')
# (4929425, 'Ford Ranger XL 2.2L 4x4 MT 2018', 18218.66405, 'Ford - Dubbo')
# (4929432, 'Honda CRV G 2018', 33198.45449, 'Honda - Brisbane')
# (4929435, 'Toyota Camry 2.5Q 2020', 40485.92011, 'Toyota - Perth')
# (4929436, 'Toyota Zace GL 2005', 6680.17682, 'Toyota - Adelaide')
# (4929443, 'Toyota Vios CVT 2017', 16963.60053, 'Toyota - Canberra')
# (4929444, 'Honda City CVT 2020 car', 19028.38245, 'Honda - Darwin')
# (4929447, 'Mitsubishi Grunder AT 2011', 17368.45973, 'Mitsubishi - Hobart')
# (4929450, 'Kia Rio 2016 car', 15182.22004, 'Kia - Gold Coast')
# (4929453, 'Toyota Yaris 1.3 AT 2009', 11740.91683, 'Toyota - Newcastle')
# (4929457, 'Toyota Corolla Cross 1.8V 2021', 31579.01769, 'Toyota - Wollongong')
# (4929462, 'Ford Ranger 2016', 25708.55927, 'Ford - Geelong')
# (4929463, 'Mazda CX5 2.0 AT 2019 car', 27327.99607, 'Mazda - Townsville')
# (4929466, 'Mazda 3 luxury 2021 car', 25101.27047, 'Mazda - Cairns')
# (4929468, 'Toyota Fortuner 2.7V 2012', 19230.81205, 'Toyota - Ballarat')
# (4929471, 'Hyundai Stargazer Premium 2022', 24089.12247, 'Hyundai - Bendigo')
# (4929472, 'Mercedes Benz C class C180 AMG 2021', 40485.92011, 'Mercedes Benz - Albury')
# (4929473, 'Honda City RS 2022 car', 20850.24886, 'Honda - Launceston')
# (4929476, 'Toyota Fortuner 2.5G 2013', 21659.96726, 'Toyota - Mackay')
# (4929477, 'Daewoo Gentra 2007 car', 3441.303209, 'Daewoo - Rockhampton')
# (4929483, 'Toyota Camry 2.5Q 2015', 26113.41847, 'Toyota - Bundaberg')
# (4929484, 'Chevrolet Spark 2009', 2631.584807, 'Chevrolet - Maitland')
# (4929485, 'Lexus RX 350 sx 2011', 40485.92011, 'Lexus - Burnie')
# (4929488, 'Honda City 1.5 TOP 2018', 18218.66405, 'Honda - Bunbury')
# (4929492, 'Hyundai i10 2016 car', 8502.04322, 'Hyundai - Gladstone')
# (4929495, 'Honda CRV L 2022 car', 38866.48331, 'Honda - Hervey Bay')
# (4929500, 'Mercedes Benz C class C300 AMG 2020', 11578.97315, 'Mercedes Benz - Alice Springs')
# (4929503, 'Honda CRV 2010', 15991.93845, 'Honda - Mount Gambier')
# (4929507, 'Honda Brio RS 2021', 17327.97381, 'Honda - Kalgoorlie')
# (4929512, 'Toyota Fortuner 2.4G MT 4x2 2017', 30323.95416, 'Toyota - Devonport')
# (4929513, 'Hyundai i10 MT fun 2022 car', 15506.1074, 'Hyundai - Mandurah')
# (4929522, 'Mazda 6 Premium 2.0AT 2020', 30162.01048, 'Mazda - Orange')
# (4929527, 'Mazda CX5 2.0G AT 4x2 2019', 29392.778, 'Mazda - Dubbo')
# (4929533, 'Toyota Vios 1.5G AT 2014', 18623.52325, 'Toyota - Sydney')
# (4929550, 'Toyota Raize G 1.0 CVT 2022', 22996.00262, 'Toyota - Melbourne')
# (4929551, 'Toyota Vios 1.5E MT 2020', 15991.93845, 'Toyota - Brisbane')
# (4929563, 'Honda City RS 2021 car', 21457.53766, 'Honda - Perth')
# (4929571, 'Kia Rio 1.4 AT 2015', 15789.50884, 'Kia - Canberra')
# (4929572, 'Ford Everest Titanium 4x2 2023 car', 40485.92011, 'Ford - Darwin')
# (4929573, 'Suzuki Swift GLX 1.2 AT 2019 car', 18137.69221, 'Suzuki - Hobart')
# (4929594, 'Ford Everest 2.2 CRDI 2016', 27854.31303, 'Ford - Newcastle')
# (4929602, 'The most advanced Hyundai Tucson 2022', 40485.92011, 'Hyundai - Wollongong')
# (4929609, 'Hyundai Creta 1.5l special car 2022', 25708.55927, 'Hyundai - Geelong')
# (4929610, 'Daewoo Lacetti 1.6EX 2009', 5060.740014, 'Daewoo - Townsville')
# (4929623, 'Hyundai SantaFe 2.4 Premium 2022 car', 40485.92011, 'Hyundai - Cairns')
# (4929627, 'Mercedes Benz GLC 200 4Matic 2022', 40485.92011, 'Mercedes Benz - Toowoomba')
# (4929630, 'VinFast Fadil 1.4AT premium 2020 car', 15182.22004, 'VinFast - Ballarat')
# (4929633, 'Mercedes Benz GLC 200 4 matic 2022', 40485.92011, 'Mercedes Benz - Bendigo')
# (4929634, 'Hyundai Getz full 2010 car', 6680.17682, 'Hyundai - Albury')
# (4929651, 'Daewoo Lacetti CDX 1.6 AT 2009', 0.008097184, 'Daewoo - Rockhampton')
# (4929660, 'Kia Cerato 1.6L Auto 2018', 18542.55141, 'Kia - Burnie')
# (4929667, 'Ford Ranger Raptor 2020', 40485.92011, 'Ford - Gladstone')
# (4929672, 'Mazda 6 2.5 premium 2016', 20850.24886, 'Mazda - Hervey Bay')
# (4929673, '2009 Hyundai Santa Fe Evgt domestic car', 21255.10806, 'Hyundai - Alice Springs')
# (4929680, 'Mazda 6 2016', 19797.61493, 'Mazda - Kalgoorlie')
# (4929692, 'Hyundai Tucson 2.0 AT CRDi Special 2021', 33562.82777, 'Hyundai - Devonport')
# (4929709, 'Nissan Navara VL 2013', 13562.78324, 'Nissan - Tamworth')
# (4929712, 'Toyota Vios 2014 car', 12145.77603, 'Toyota - Orange')
# (4929715, 'Toyota Fortuner 2016', 27327.99607, 'Toyota - Dubbo')
# (4929720, 'Ford Ranger 2.2 2019', 21457.53766, 'Ford - Sydney')
# (4929727, 'Hyundai i10 1.2 AT 2021 car', 15991.93845, 'Hyundai - Brisbane')
# (4929729, 'Hyundai i10 Hackback 2016', 11659.94499, 'Hyundai - Perth')
# (4929733, 'Kia Seltos Luxury 2020 car', 25060.78455, 'Kia - Canberra')
# (4929741, 'Toyota Hilux 2.4 AT 2019', 23805.72103, 'Toyota - Hobart')
# (4929747, 'Honda Civic 1.8MT 2008', 9109.332027, 'Honda - Gold Coast')
# (4929752, 'Chevrolet Aveo AT 2016', 10850.22659, 'Chevrolet - Newcastle')
# (4929757, 'Toyota Innova 2.0G 2018', 24291.55207, 'Toyota - Wollongong')
# (4929763, 'Mercedes Benz C class 300 AMG 2019', 11578.97315, 'Mercedes Benz - Geelong')
# (4929768, 'Kia Soluto AT 2020 car', 15384.64964, 'Kia - Townsville')
# (4929772, 'Toyota Corolla altis 2014', 19230.81205, 'Toyota - Toowoomba')
# (4929773, 'Mitsubishi Jolie 2005 car', 4251.021611, 'Mitsubishi - Ballarat')
# (4929779, 'Mazda 3 1.5 Luxury 2022', 25870.50295, 'Mazda - Bendigo')
# (4929782, 'Hyundai SantaFe 2.4 Premium 2021 car', 40485.92011, 'Hyundai - Albury')
# (4929785, 'Ford Everest 2019 car', 35465.66601, 'Ford - Launceston')
# (4929792, 'Chevrolet Spark AT 2013', 6072.888017, 'Chevrolet - Mackay')
# (4929793, 'Mercedes Benz GLC 300 4Matic model 2019', 40485.92011, 'Mercedes Benz - Rockhampton')
# (4929796, 'Ford Focus Titanium 1.5L 2019', 19635.67125, 'Ford - Bundaberg')
# (4929800, 'Hyundai i10 Sedan 1.2AT 2021', 15991.93845, 'Hyundai - Burnie')
# (4929801, 'Honda Civic 1.8 MT 2006', 0.008097184, 'Honda - Bunbury')
# (4929804, 'Hyundai Click 1.4 AT 2008 car', 7489.89522, 'Hyundai - Gladstone')
# (4929810, 'Mercedes Benz GLC 250 2016', 40485.92011, 'Mercedes Benz - Hervey Bay')
# (4929813, 'Mazda CX5 2.0 AT AWD 2014', 20850.24886, 'Mazda - Alice Springs')
# (4929814, 'Toyota Hilux 2.4AT 2020', 27125.56647, 'Toyota - Mount Gambier')
# (4929820, 'Kia Sorento 2.2 DATH 2014', 22469.68566, 'Kia - Kalgoorlie')
# (4929823, 'Toyota Corolla Cross 1.8G 2022', 30364.44008, 'Toyota - Devonport')
# (4929827, 'Ford Everest Titanium 2.0L 4x2 AT 2019', 35587.12378, 'Ford - Mandurah')
# (4929830, 'Kia Sorento DATH 2017 car', 27449.45383, 'Kia - Tamworth')
# (4929835, 'Ford Fiesta 1.5 2013', 9635.648987, 'Ford - Orange')
# (4929836, 'Toyota Vios E MT 2017', 15344.16372, 'Toyota - Dubbo')
# (4929848, 'Honda CRV L 1.5Tubor 2018', 33198.45449, 'Honda - Sydney')
# (4929849, 'Mazda 3 Duluxe 2020', 23279.40407, 'Mazda - Melbourne')
# (4929852, 'Nissan Teana 2.0 AT 2010 car', 13562.78324, 'Nissan - Brisbane')
# (4929855, 'Honda Civic 1.8 AT 2008', 10323.90963, 'Honda - Perth')
# (4929858, 'Changan CX20 AT 2014 car', 7287.46562, 'Changan - Adelaide')
# (4929870, 'Toyota Innova 2017 car', 19392.75573, 'Toyota - Hobart')
# (4929874, 'Toyota Camry 2.0E 2016', 25870.50295, 'Toyota - Newcastle')
# (4929875, 'Toyota Hilux 2.4L 4x2 AT 2021', 26923.13687, 'Toyota - Wollongong')
# (4929885, 'VinFast Fadil 1.4 AT 2021 car', 15060.76228, 'VinFast - Toowoomba')
# (4929904, 'Kia Morning SX 2011 car', 8583.015067, 'Kia - Ballarat')
# (4929905, 'Toyota Vios 1.5E 2015', 12955.49443, 'Toyota - Bendigo')
# (4929915, 'Kia Rio 1.4AT Hatback 2012', 12469.66339, 'Kia - Albury')
# (4929936, 'Kia K3 1.6MT 2015', 12145.77603, 'Kia - Mackay')
# (4929944, 'Chevrolet Spark Lite Van 0.8 MT 2015', 4251.021611, 'Chevrolet - Bundaberg')
# (4929947, 'Mazda CX5 Deluxe 2.0 AT 2021 car', 29959.58088, 'Mazda - Maitland')
# (4929948, 'Kia Morning S AT 2018 car', 13724.72692, 'Kia - Burnie')
# (4929949, 'Mazda CX5 Premium 2018', 27044.59463, 'Mazda - Bunbury')
# (4929950, 'Toyota Corolla Cross V 2021', 33198.45449, 'Toyota - Gladstone')
# (4929951, 'Toyota Corolla Cross 1.8V 2020', 31012.21481, 'Toyota - Hervey Bay')
# (4929952, 'Mazda CX5 2.0AT 2018', 26923.13687, 'Mazda - Alice Springs')
# (4929957, 'Kia K3 2.0 AT 2014 car', 15789.50884, 'Kia - Kalgoorlie')
# (4929959, 'BMW 3 Series 320i 2016', 30364.44008, 'BMW - Devonport')
# (4929961, 'Mercedes Benz E class E300 AMG 2016', 40485.92011, 'Mercedes Benz - Tamworth')
# (4929963, 'Kia Optima 2.0 AT 2014', 19028.38245, 'Kia - Dubbo')
# (4929964, 'Mazda 3 FaceLift 2017', 20040.53045, 'Mazda - Sydney')
# (4929966, 'Hyundai Accent 1.4 AT 2018', 17732.83301, 'Hyundai - Melbourne')
# (4929968, 'Kia Morning Si 2018 car', 13360.35363, 'Kia - Perth')
# (4929970, 'Mercedes Benz C class C250 Eclusive 2017', 36032.4689, 'Mercedes Benz - Canberra')
# (4929972, 'Mazda 3 2.0 AT 2015', 18825.95285, 'Mazda - Hobart')
# (4929973, 'Honda CRV G 2021 car', 36437.3281, 'Honda - Gold Coast')
# (4929974, 'Hyundai i10 Grand 1.2 AT 2018 car', 13967.64244, 'Hyundai - Newcastle')
# (4929975, 'Kia Morning Base 2018 car', 9392.733467, 'Kia - Wollongong')
# (4929977, 'Toyota Fortuner 2.7V 4X2 AT 2016', 23279.40407, 'Toyota - Geelong')
# (4929979, 'Mitsubishi Xpander 1.5 AT 2019', 21821.91094, 'Mitsubishi - Townsville')
# (4930002, 'Toyota Vios 1.5E 2017', 14777.36084, 'Toyota - Cairns')
# (4930015, 'Toyota Vios 1.5E 2021 car', 16599.22725, 'Toyota - Toowoomba')
# (4930047, 'Toyota Camry 2.5Q 2020', 40485.92011, 'Toyota - Bendigo')
# (4930048, 'Mazda 3 1.5 luxury 2016', 18421.09365, 'Mazda - Albury')
# (4930049, 'VinFast Lux SA 2.0 Advanced 2022 car', 34413.03209, 'VinFast - Launceston')
# (4930054, 'Mercedes Benz E class E200 2019', 40485.92011, 'Mercedes Benz - Mackay')
# (4930057, 'Kia Morning 2015 car', 7894.75442, 'Kia - Rockhampton')
# (4930062, 'Hyundai Accent 2022 car', 19838.10085, 'Hyundai - Bundaberg')
# (4930068, 'Ford Focus Domestic 2019', 23805.72103, 'Ford - Burnie')
# (4930069, 'Toyota Innova 2017 car', 20161.98821, 'Toyota - Bunbury')
# (4930070, 'Kia Cerato 2.0 AT Premium 2021 car', 23076.97446, 'Kia - Gladstone')
# (4930073, 'Hyundai Accent 1.4AT 2013', 13967.64244, 'Hyundai - Hervey Bay')
# (4930081, 'Mitsubishi Xpander 1.5 AT 2020', 23886.69287, 'Mitsubishi - Kalgoorlie')
# (4930082, 'Toyota Veloz 1.5 CVT 2022', 26518.27767, 'Toyota - Devonport')
# (4930083, 'Ford Fiesta 2018', 15303.6778, 'Ford - Mandurah')
# (4930086, 'Hyundai Accent 1.4 MT 2020', 17408.94565, 'Hyundai - Tamworth')
# (4930087, 'Toyota Hilux G 2.8AT 4WD 2018', 29757.15128, 'Toyota - Orange')
# (4930090, 'Hyundai Accent 1.4 MT 2021', 18016.23445, 'Hyundai - Dubbo')
# (4930091, 'Mercedes Benz GLC 250 2017', 40485.92011, 'Mercedes Benz - Sydney')
# (4930092, 'Hyundai i10 1.2 AT 2020 car', 14777.36084, 'Hyundai - Melbourne')
# (4930093, 'Kia K3 2.0 2015 car', 16842.14277, 'Kia - Brisbane')
# (4930094, 'Kia Sorento 2021', 40485.92011, 'Kia - Perth')
# (4930095, 'Hyundai Elantra 2.0 2017', 18623.52325, 'Hyundai - Adelaide')
# (4930098, 'Hyundai i10 Grand 1.2 MT 2019', 13157.92403, 'Hyundai - Canberra')
# (4930099, 'Nissan Teana 2.0 2010 car', 12550.63523, 'Nissan - Darwin')
# (4930100, 'Toyota Camry 2.5Q 2023', 13157.92403, 'Toyota - Hobart')
# (4930103, 'Ford Ranger XLS AT 4x2 Thai 2017', 21255.10806, 'Ford - Gold Coast')
# (4930105, 'Toyota Vios 2019 car', 14939.30452, 'Toyota - Newcastle')
# (4930106, 'Toyota Corolla Cross Hybrid 2022', 35870.52522, 'Toyota - Wollongong')
# (4930110, 'Peugeot 5008 GT 2021', 40485.92011, 'Peugeot - Geelong')
# (4930111, 'Mercedes Benz C class C300 AMG 2020', 11578.97315, 'Mercedes Benz - Townsville')
# (4930114, 'Ssangyong Rexton 2.5 2006', 7894.75442, 'Ssangyong - Cairns')
# (4930118, 'Mazda 3 2018', 19230.81205, 'Mazda - Ballarat')
# (4930119, 'Ford EcoSport Titanium 2016', 16801.65685, 'Ford - Bendigo')
# (4930120, 'Toyota Vios 1.5G 2018', 17408.94565, 'Toyota - Albury')
# (4930123, 'MG ZS Comfort 1.5 AT 2WD 2020', 20202.47413, 'MG - Launceston')
# (4930124, 'Kia Morning 2015 car', 8906.902427, 'Kia - Mackay')
# (4930128, 'Hyundai i10 1.2 AT 2021 car', 15991.93845, 'Hyundai - Rockhampton')
# (4930129, 'Toyota Camry 2.5Q 2017', 29959.58088, 'Toyota - Bundaberg')
# (4930130, 'Nissan X trail AT 2017 car', 24089.12247, 'Nissan - Maitland')
# (4930144, 'Mercedes Benz GLC 200 2020', 40485.92011, 'Mercedes Benz - Gladstone')

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## a. Static Data Visualisation

# %%
# Load the cleaned dataset
car_data = pd.read_csv('cleaned_car_dataset.csv')

# %% [markdown]
# ### i. Relationship between 'mileage' and 'price'

# %%
plt.figure(figsize=(10, 6))

sns.regplot(x='mileage', y='price (AUD)', data=car_data, label='Car Data',
            scatter_kws={'color': 'royalblue', 'alpha': 0.2, 's': 10})
sns.regplot(x='mileage', y='price (AUD)', data=car_data, scatter=False, label='Regression Line',
            line_kws={'color': 'red'})

plt.title('Relationship between Mileage and Price', fontsize=14)
plt.xlabel('Mileage', fontsize=12)
plt.ylabel('Price (AUD)', fontsize=12)

plt.legend(title='Legend', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# The scatter plot above shows a negative trend between mileage and price, with higher mileage generally correlating to lower prices, as indicated by the downward-sloping trendline. However, there is significant variability, particularly at lower mileages, where prices still range widely. This suggests that while mileage affects pricing, other factors also play a role.

# %% [markdown]
# ### ii. Trend of car prices over the 'year_of_m'

# %%
year_price_mean = car_data.groupby('year_of_manufacture')['price (AUD)'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=year_price_mean, x='year_of_manufacture', y='price (AUD)', marker='o', color='#2ca02c', linewidth=2, label='Average Price Trend')

plt.title('Trend of Car Prices over Year of Manufacture', fontsize=16)
plt.xlabel('Year of Manufacture', fontsize=14)
plt.ylabel('Average Price (AUD)', fontsize=14)

years = year_price_mean['year_of_manufacture']
plt.xticks(rotation=45, ticks=years[::2])

plt.grid(True, which='both', linestyle='--', linewidth=0.7, alpha=0.7)
plt.legend(title='Legend', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# The line graph above shows a clear upward trend in car prices over the years of manufacture, indicating that newer cars generally have higher average prices. From 2005 to 2023, there is a steady increase, with significant price growth after 2010. The consistent rise suggests that factors such as newer technology, improved features, and perhaps inflation may contribute to this trend. This implies that the year of manufacture is an important factor in determining the price, with more recent cars typically being priced higher.

# %% [markdown]
# ### iii. Average prices among different 'car_models'

# %%
car_data_filtered = car_data[car_data['car_model'] != 'wagon']

model_price_mean = car_data_filtered.groupby('car_model')['price (AUD)'].mean().reset_index()
model_price_mean = model_price_mean.sort_values(by='price (AUD)', ascending=False)

plt.figure(figsize=(12, 8))
sns.set_style('whitegrid')

bar_plot = sns.barplot(data=model_price_mean, x='car_model', y='price (AUD)', hue='car_model', palette='crest_r') # viridis

plt.title('Average Price of Different Car Models (Excluding Wagon)', fontsize=16)
plt.xlabel('Car Model', fontsize=14)
plt.ylabel('Average Price (AUD)', fontsize=14)

plt.xticks(rotation=45, ha='right', fontsize=12)

for bar, label in zip(bar_plot.patches, model_price_mean['car_model']):
    bar.set_label(label)

plt.legend(title='Car Models', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# The bar chart above compares the average prices of different car models. SUVs and convertibles/cabriolets have the highest average prices, both around 30,000 AUD, followed by coupes and 4x4s, which also show relatively high prices. Crossovers, sedans, and vans/minivans are in the middle range, while trucks are priced lower on average. Hatchbacks have the lowest average price, falling well below 20,000 AUD. This suggests that larger vehicles, such as SUVs and convertibles, tend to be more expensive, while smaller models like hatchbacks are generally more affordable.

# %% [markdown]
# ### iv. Distribution of ‘engine_capacity’

# %%
plt.figure(figsize=(12, 6))

ax = sns.histplot(data=car_data, x='engine_capacity', bins=20, kde=True, color='skyblue', edgecolor='black', alpha=0.6)
ax.lines[0].set_color('crimson')

plt.title('Distribution of Engine Capacity', fontsize=16)
plt.xlabel('Engine Capacity (L)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

plt.grid(True, which='both', linestyle='--', linewidth=0.7, alpha=0.7)
plt.legend(labels=['KDE Curve', 'Engine Capacity Histogram'], title='Legend', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# The histogram and KDE curve above show the distribution of engine capacity. The data is bimodal, with two prominent peaks around 1.5L and 2.0L, indicating that most cars in the dataset have engines around these sizes. There are smaller groups of cars with engine capacities below 1.0L and a few with larger engines, up to around 3.5L. The distribution tails off as engine capacity increases, suggesting that higher-capacity engines are less common in the dataset. Overall, the most frequent engine sizes are between 1.0L and 2.0L.

# %% [markdown]
# ### v. Distribution of the cars’ exterior colors as the percentage of a whole

# %%
car_data = car_data[car_data['exterior_color'] != 'take note']

color_counts = car_data['exterior_color'].value_counts()

total_count = color_counts.sum()
threshold = 0.01 * total_count

top_colors = color_counts[color_counts >= threshold]
other_total = color_counts[color_counts < threshold].sum()

if other_total > 0:
    top_colors = pd.concat([top_colors, pd.Series({'Other': other_total})])

color_percentages = top_colors / total_count * 100

# Map each exterior color to its corresponding actual color
color_mapping = {
    'white': '#f0f0f0',
    'black': 'black',
    'red': 'red',
    'silver': 'silver',
    'green': 'green',
    'grey': 'grey',
    'brown': 'saddlebrown',
    'sand': 'sandybrown',
    'yellow': 'gold',
    'orange': 'orange',
    'Other': 'dodgerblue'
}

colors_to_use = [color_mapping.get(color, 'dodgerblue') for color in color_percentages.index]
explode_values = [0.1 if color == 'white' else 0 for color in color_percentages.index]

plt.figure(figsize=(8, 8))
patches, texts, autotexts = plt.pie(
    color_percentages,
    explode=explode_values,
    labels=None,
    colors=colors_to_use,
    autopct=lambda pct: '{:.1f}%'.format(pct) if pct >= 1.5 else '',
    pctdistance=0.85,
    startangle=180,
    wedgeprops={'linewidth': 1, 'edgecolor': 'white', 'alpha': 0.7}
)

for i, autotext in enumerate(autotexts):
    autotext.set_fontsize(12)
    if color_percentages.index[i] == 'white':
        autotext.set_color('black')
    else:
        autotext.set_color('white')

plt.legend(title='Exterior Colors', labels=top_colors.index, loc="upper right", bbox_to_anchor=(1.2, 0.7))
plt.title('Distribution of Exterior Colors', fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# The pie chart above displays the distribution of cars' exterior colours. White is the most common colour, accounting for 33.5% of the total, followed by black at 19.6% and red at 14.9%. Silver is also prevalent, making up 10.1%. Other colours, such as green, grey, brown, sand, yellow, orange, and others, represent smaller portions, with green being the most common among them at 7.4%. Overall, neutral car colours like white, black, and silver dominate, while more vibrant colours are less common.

# %% [markdown]
# ### vi. Correlations between specified features

# %%
plt.figure(figsize=(8, 6))

corr_matrix = car_data[['mileage', 'num_of_doors', 'seating_capacity', 'fuel_consumption', 'price (AUD)']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

plt.title('Correlation Matrix of Selected Car Features', fontsize=14)
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# The correlation matrix above reveals several key relationships between the selected car features. Mileage has a moderate negative correlation with price (-0.22), indicating that higher mileage generally leads to lower prices. Fuel consumption has a moderate positive correlation with price (0.36), suggesting that cars with higher fuel consumption tend to have higher prices. Seating capacity also shows a moderate correlation with both the number of doors (0.43) and fuel consumption (0.33). Other correlations are relatively weak, such as mileage with fuel consumption (0.19) and price with seating capacity (0.19), indicating that these features don't have a strong connection. Additionally, some features show very low correlations. For example, mileage and seating capacity (0.0012), as well as the number of doors and fuel consumption (0.054), show almost no relationship, suggesting these features are largely independent of each other and don't influence one another in a meaningful way.

# %% [markdown]
# ## b. Interactive Visualization Enhancement

# %% [markdown]
# ### Link to completed ObservableHQ notebook:
# ### https://observablehq.com/d/f60da854f4fc5dff
